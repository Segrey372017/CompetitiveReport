# %% [markdown]
# <a href="https://colab.research.google.com/github/Segrey372017/CompetitiveReport/blob/main/buisiness_poll_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
link = "https://github.com/Segrey372017/CompetitiveReport/blob/main/2022_%D0%9E%D0%BF%D1%80%D0%BE%D1%81_%D0%BF%D1%80%D0%B5%D0%B4%D0%BF%D1%80%D0%B8%D0%BD%D0%B8%D0%BC%D0%B0%D1%82%D0%B5%D0%BB%D0%B5%D0%B9_2021.xlsx?raw=true"

# %%
data = pd.read_excel(link)

# %%
data.head()
# Out:
#           Отметка времени  ...  Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Теплоснабжение]
# 0 2022-01-14 10:02:21.029  ...                                         Улучшилось
# 1 2022-01-14 10:20:29.938  ...                                         Ухудшилось
# 2 2022-01-14 10:28:47.653  ...                                      Не изменилось
# 3 2022-01-14 10:42:39.439  ...                                      Не изменилось
# 4 2022-01-14 10:59:17.332  ...                                         Улучшилось
#
# [5 rows x 119 columns]

# %%
for i in range(len(data.columns)):
    print(i,'. ',data.columns[i])
# Out:
# 0 .  Отметка времени
# 1 .  В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?
# 2 .  В какой форме вы осуществляете предпринимательскую деятельность?(выберите один вариант ответа)
# 3 .  В течении какого периода времени Ваш бизнес осуществляет свою деятельность? (пожалуйста, выберите один вариант ответа)
# 4 .  Какую должность Вы занимаете в организации, которую Вы представляете? (пожалуйста, выберите один вариант ответа)
# 5 .  Какова численность сотрудников Вашей организации в настоящее время? (пожалуйста, выберите один вариант ответа)
# 6 .  Какова примерная величина годового оборота бизнеса, который вы представляете? (пожалуйста, выберите один вариант ответа)
# 7 .  В какой сфере Вы осуществляете экономическую деятельность  (основной род занятий) в соответствии с ОКВЭД?
# ...

# %%
def make_hist(d_info):
    "Выодит гистограму по полученным данным"
    plt.figure(figsize= (8,6))
    sns.histplot(d_info)
    plt.xticks(rotation = 90)
    plt.ylabel('Число опрошенных')
    plt.show()
    return

# %%
def calc_percent(cnt, r = 2):
    """ Считает процентное соотношение числа опрошенных,всего опрошенных 100%
        r - окгугление до r знаков после запятой
    """
    s = sum(cnt.values())
    p_cnt = dict()

    for key in cnt.keys():
        p_cnt[key] = round(cnt[key] / s * 100, r)

    p_cnt['Всего'] = s
    return p_cnt

# %%
from collections import Counter
cities = dict(Counter(data[data.columns[1]]).most_common())
print(cities)
print(calc_percent(cities))
# Out:
# {'Городской округ Кинешма': 69, 'Городской округ Иваново': 45, 'Лежневский муниципальный район': 40, 'Городской округ Кохма': 40, 'Южский муниципальный район': 34, 'Городской округ Вичуга': 33, 'Пестяковский муниципальный район': 33, 'Родниковский муниципальный район': 32, 'Комсомольский муниципальный район': 32, 'Тейковский муниципальный район': 32, 'Заволжский муниципальный район': 31, 'Вичугский муниципальный район': 31, 'Верхнеландеховский муниципальный район': 31, 'Городской округ Шуя': 31, 'Лухский муниципальный район': 31, 'Ильинский муниципальный район': 30, 'Кинешемский муниципальный район': 30, 'Савинский муниципальный район': 30, 'Шуйский муниципальный район': 30, 'Фурмановский муниципальный район': 30, 'Гаврилово-Посадский муниципальный район': 30, 'Пучежский муниципальный район': 30, 'Ивановский муниципальный район': 29, 'Городской округ Тейково': 28, 'Приволжский муниципальный район': 26, 'Палехский муниципальный район': 17, 'Юрьевецкий муниципальный район': 14}
# ...

# %%
make_hist(data.iloc[:, 1])

# %%
kin_index = data.index[data[data.columns[1]].values=='Городской округ Кинешма']
kin_data = data.iloc[kin_index,:]
del data

# %%
kin_data.head()
# Out:
#             Отметка времени  ...  Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Теплоснабжение]
# 640 2022-01-27 10:17:31.105  ...                                                NaN
# 641 2022-01-27 10:32:54.648  ...                                                NaN
# 643 2022-01-27 10:53:29.146  ...                                                NaN
# 644 2022-01-27 10:56:01.799  ...                                                NaN
# 645 2022-01-27 10:57:21.229  ...                                                NaN
#
# [5 rows x 119 columns]

# %%
# Форма осуществления деятельности
form = dict(Counter(kin_data.iloc[:, 2]).most_common())
print(form)
print(calc_percent(form))
del form
# Out:
# {'Индивидуальный предприниматель': 35, 'Юридическое лицо': 34}
# {'Индивидуальный предприниматель': 50.72, 'Юридическое лицо': 49.28, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 2])

# %%
#  В течении какого периода времени Ваш бизнес осуществляет свою деятельность?
b_age = dict(Counter(kin_data.iloc[:, 3]).most_common())
print(b_age)
print(calc_percent(b_age))
del b_age
# Out:
# {'Более 5 лет': 37, 'от 1 года до 5 лет': 32}
# {'Более 5 лет': 53.62, 'от 1 года до 5 лет': 46.38, 'Всего': 69}

# %%
# Какую должность Вы занимаете в организации, которую Вы представляете?
employee = dict(Counter(kin_data.iloc[:, 4]).most_common())
print(employee)
print(calc_percent(employee))
del employee
# Out:
# {'Собственник бизнеса (владелец)': 52, 'Руководитель высшего звена (генеральный директор, заместитель генерального директора)': 17}
# {'Собственник бизнеса (владелец)': 75.36, 'Руководитель высшего звена (генеральный директор, заместитель генерального директора)': 24.64, 'Всего': 69}

# %%
# Какова численность сотрудников Вашей организации в настоящее время?
employee = dict(Counter(kin_data.iloc[:, 5]).most_common())
print(employee)
print(calc_percent(employee))
del employee
# Out:
# {'До 15 человек': 50, 'От 16 до 100 человек': 19}
# {'До 15 человек': 72.46, 'От 16 до 100 человек': 27.54, 'Всего': 69}

# %%
# Какова примерная величина годового оборота бизнеса, который вы представляете?
turnover = dict(Counter(kin_data.iloc[:, 6]).most_common())
print(turnover)
print(calc_percent(turnover))
del turnover
# Out:
# {'До 120 млн. рублей (микропредприятие)': 69}
# {'До 120 млн. рублей (микропредприятие)': 100.0, 'Всего': 69}

# %%
# К какой социально-значимой сфере экономической деятельности относится деятельность бизнеса, которой вы представляете?
otrasl = dict(Counter(kin_data.iloc[:, 7]).most_common())
print(otrasl)
print(calc_percent(otrasl))
del otrasl
# Out:
# {'Раздел G. Торговля оптовая и розничная; ремонт автотранспортных средств и мотоциклов': 24, 'Раздел F. Строительство': 23, 'Раздел H. Транспортировка и хранение': 18, 'Раздел L. Деятельность по операциям с недвижимым имуществом': 3, 'Раздел C. Обрабатывающие производства': 1}
# {'Раздел G. Торговля оптовая и розничная; ремонт автотранспортных средств и мотоциклов': 34.78, 'Раздел F. Строительство': 33.33, 'Раздел H. Транспортировка и хранение': 26.09, 'Раздел L. Деятельность по операциям с недвижимым имуществом': 4.35, 'Раздел C. Обрабатывающие производства': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 7])

# %%
# В какой сфере Вы осуществляете экономическую деятельность  (основной род занятий) в соответствии с ОКВЭД?
okved = dict(Counter(kin_data.iloc[:, 118]).most_common())
print(okved)
print(calc_percent(okved))
del okved
# Out:
# {nan: 69}
# {nan: 100.0, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 118])

# %%
# ОСНОВНОЙ ПРОДУКЦИЕЙ (ТОВАРОМ, РАБОТОЙ, УСЛУГОЙ) БИЗНЕСА, КОТОРЫЙ ВЫ ПРЕДСТАВЛЯЕТЕ, ЯВЛЯЕТСЯ:
product = dict(Counter(kin_data.iloc[:, 8]).most_common())
print(product)
print(calc_percent(product))
del product
# Out:
# {'Рынок легкой промышленности': 28, 'Социальные услуги': 16, 'Работы по благоустройству городской среды': 14, 'Строительство': 10, 'Рынок производства бетона': 1}
# {'Рынок легкой промышленности': 40.58, 'Социальные услуги': 23.19, 'Работы по благоустройству городской среды': 20.29, 'Строительство': 14.49, 'Рынок производства бетона': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 8])

# %%
# Какую именно продукцию (товары, работы, услуги) реализует бизнес, который вы представляете?
product = dict(Counter(kin_data.iloc[:, 9]).most_common())
print(product)
print(calc_percent(product))
del product
# Out:
# {'Бизнес осуществляет торговлю или дистрибуцию товаров и услуг, произведенных другими компаниями': 45, 'Конечная продукция': 13, 'Компоненты для производства конечной продукции': 11}
# {'Бизнес осуществляет торговлю или дистрибуцию товаров и услуг, произведенных другими компаниями': 65.22, 'Конечная продукция': 18.84, 'Компоненты для производства конечной продукции': 15.94, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 9])

# %%
# Укажите, какие меры по повышению конкурентоспособности продукции, работ, услуг, которые производит или предоставляет Ваш бизнес
mesures = dict(Counter(kin_data.iloc[:, 10]).most_common())
print(mesures)
print(calc_percent(mesures))
del mesures
# Out:
# {'продукты': 9, 'крепеж': 9, 'хозтовары': 9, 'метизы': 5, 'дома из бруса': 4, 'Cтроительство и ремонт': 4, 'ремонт квартир , офисов': 4, 'cтроительство нежилых зданий': 4, 'торговля обувью': 3, 'прокладка коммуникаций': 3, 'торговли одеждой, обувью': 2, 'ИЖС': 2, 'дома коттеджи': 2, 'полуфабрикаты, рыба': 2, 'продовольственые и непродовольственные товары': 2, 'продукы питания': 2, 'детская обувь': 1, 'стройматериалы': 1, 'средства индивидуальной защиты': 1}
# {'продукты': 13.04, 'крепеж': 13.04, 'хозтовары': 13.04, 'метизы': 7.25, 'дома из бруса': 5.8, 'Cтроительство и ремонт': 5.8, 'ремонт квартир , офисов': 5.8, 'cтроительство нежилых зданий': 5.8, 'торговля обувью': 4.35, 'прокладка коммуникаций': 4.35, 'торговли одеждой, обувью': 2.9, 'ИЖС': 2.9, 'дома коттеджи': 2.9, 'полуфабрикаты, рыба': 2.9, 'продовольственые и непродовольственные товары': 2.9, 'продукы питания': 2.9, 'детская обувь': 1.45, 'стройматериалы': 1.45, 'средства индивидуальной защиты': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 10])

# %%
# Какой географический рынок (рынки) является основным* для бизнеса
area = dict(Counter(kin_data.iloc[:, 11]).most_common())
print(area)
print(calc_percent(area))
del area
# Out:
# {'Новые способы продвижения продукции (маркетинговые стратегии)': 46, 'Приобретение технического оборудования': 13, 'Обучение и переподготовка персонала': 10}
# {'Новые способы продвижения продукции (маркетинговые стратегии)': 66.67, 'Приобретение технического оборудования': 18.84, 'Обучение и переподготовка персонала': 14.49, 'Всего': 69}

# %%
# Выберите утверждение, наиболее точно характеризующее условия ведения бизнеса, который вы представляете.
answer = dict(Counter(kin_data.iloc[:, 12]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Рынок Ивановской области': 39, 'Локальный рынок (отдельное муниципальное образование)': 27, 'Рынки нескольких субъектов Российской Федерации': 3}
# {'Рынок Ивановской области': 56.52, 'Локальный рынок (отдельное муниципальное образование)': 39.13, 'Рынки нескольких субъектов Российской Федерации': 4.35, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 12])

# %%
# Оцените примерное количество конкурентов бизнеса, который вы представляете
answer = dict(Counter(kin_data.iloc[:, 13]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно ( раз в год и чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) – умеренная конкуренция': 45, 'Для сохранения рыночной позиции нашего бизнеса время от времени (раз в 2-3года) может потребоваться реализация мер по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) – слабая конкуренция': 14, 'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно ( раз в год и чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное), а также время от времени (раз в 2-3года) применять новые способные повышения, не используемые компанией ранее – высокая конкуренция': 10}
# ...

# %%
make_hist(kin_data.iloc[:, 13])

# %%
# Как изменилось число конкурентов бизнеса, который вы представляете, на основном рынке товаров и услуг за последние 3 года?
answer = dict(Counter(kin_data.iloc[:, 14]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'От 4 до 8 конкурентов': 43, 'Большое число конкурентов': 17, 'От 1 до 3 конкурентов': 9}
# {'От 4 до 8 конкурентов': 62.32, 'Большое число конкурентов': 24.64, 'От 1 до 3 конкурентов': 13.04, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 14])

# %%
# Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг ивановской области
from IPython.display import HTML, display
st = 15
end =17 

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Как изменилось число конкурентов бизнеса, который вы представляете, на основном рынке товаров и услуг за последние 3 года? (пожалуйста, выберите один вариант ответа) </td><td> Сократилось на 1-3 конкурента </td>  <td> 42 </td><td> Не изменилось </td>  <td> 14 </td><td> Увеличилось на 1-3 конкурента </td>  <td> 13 </td></tr><tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг ивановской области и деятельности по содействию развитию конкуренции, размещаемой в открытом доступе. [Уровень доступности] </td><td> Скорее удовлетворительное </td>  <td> 44 </td><td> Скорее неудовлетворительное </td>  <td> 19 </td><td> Удовлетворительное </td>  <td> 6 </td></tr><tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг ивановской области и деятельности по содействию развитию конкуренции, размещаемой в открытом доступе. [Уровень понятности] </td><td> Скорее удовлетворительное <
# ...

# %%
# Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации
st = 18
end = 23 

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг ивановской области и деятельности по содействию развитию конкуренции, размещаемой в открытом доступе. [Удобство получения] </td><td> Скорее удовлетворительное </td>  <td> 40 </td><td> Скорее неудовлетворительное </td>  <td> 15 </td><td> Удовлетворительное </td>  <td> 14 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг  и деятельности по содействию развитию конкуренции [Доступность информации о нормативной базе, связанной с внедрением Стандарта в регионе] </td><td> Скорее удовлетворительно </td>  <td> 45 </td><td> Удовлетворительно </td>  <td> 16 </td><td> Скорее неудовлетворительно </td>  <td> 8 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исп
# ...

# %%
#  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации
st = 24
end = 31 

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг  и деятельности по содействию развитию конкуренции [Доступность информации о проведенных мониторингах в регионе и сформированном ежегодном докладе] </td><td> Скорее удовлетворительно </td>  <td> 36 </td><td> Скорее неудовлетворительно </td>  <td> 19 </td><td> Удовлетворительно </td>  <td> 14 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг и и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего? [Официальная информация, размещенная на сайте уполномоченного органа в информационно-телекоммуникационной сети "Интернет"] </td><td> Доверяю больше всего </td>  <td> 40 </td><td> Затрудняюсь ответить </td>  <td> 15 </td><td> Предпочит
# ...

# %%
# Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает
st = 32
end = 33

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг и и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего? [Специальные блоги, порталы и прочие электронные ресурсы] </td><td> Доверяю больше всего </td>  <td> 39 </td><td> Предпочитаю пользоваться </td>  <td> 19 </td><td> Затрудняюсь ответить </td>  <td> 11 </td></tr><tr> <td> Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги),  а также вашу удовлетворенность состоянием конкуренции между поставщиками этого товара (пожалуйста, выберите один вариант ответа для каждой строки) [Число поставщиков основного закупаемого товара (работы, услуги)] </td><td> 2-3 поставщика/ Скорее неудовлетворительно </td>  <td> 35 </td><td> Единственный поставщик/Неудовлетворительно </td>  <td> 34 </td></tr></table>

# %%
# ПОЖАЛУЙСТА, УКАЖИТЕ НАИМЕНОВАНИЕ ОСНОВНОГО ЗАКУПАЕМОГО ТОВАРА (РАБОТЫ, УСЛУГИ)
answer = dict(Counter(kin_data.iloc[:, 34]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'2-3 поставщика/ Скорее неудовлетворительно': 37, 'Единственный поставщик/Неудовлетворительно': 31, '4 и более поставщика/Скорее удовлетворительно': 1}
# {'2-3 поставщика/ Скорее неудовлетворительно': 53.62, 'Единственный поставщик/Неудовлетворительно': 44.93, '4 и более поставщика/Скорее удовлетворительно': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 34])

# %%
# Пожалуйста, укажите наименование товаров, работ, услуг, закупаемых представляемым вами бизнесом для производства
answer = dict(Counter(kin_data.iloc[:, 35]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'топливо': 32, 'тара, упаковка': 12, 'материалы': 12, 'канцтовары': 6, 'металл': 4, 'сырье': 2, 'детская обувь': 1}
# {'топливо': 46.38, 'тара, упаковка': 17.39, 'материалы': 17.39, 'канцтовары': 8.7, 'металл': 5.8, 'сырье': 2.9, 'детская обувь': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 35])

# %%
# КАКОЙ ОТРАСЛЕВОЙ РЫНОК В ВАШЕМ РАЙОНЕ/ГОРОДСКОМ ОКРУГЕ ВЫ СЧИТАЕТЕ ПРИОРИТЕТНЫМИ И СОЦИАЛЬНО-ЗНАЧИМЫМИ
answer = dict(Counter(kin_data.iloc[:, 36]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'жкх': 19, 'энергетика': 17, 'металл': 8, 'топливо': 8, 'электроснабжение': 7, 'ГСМ': 7, 'коммунальные ресурсы': 2, 'теплоэнергия': 1}
# {'жкх': 27.54, 'энергетика': 24.64, 'металл': 11.59, 'топливо': 11.59, 'электроснабжение': 10.14, 'ГСМ': 10.14, 'коммунальные ресурсы': 2.9, 'теплоэнергия': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 36])

# %%
# СЧИТАЕТЕ ЛИ ВЫ, ЧТО КОНКУРЕНЦИЯ НА ВАШЕМ ОТРАСЛЕВОМ РЫНКЕ В ВАШЕМ РАЙОНЕ/ГОРОДСКОМ ОКРУГЕ ИМЕЕТ ВЫСОКИЙ УРОВЕНЬ РАЗВИТИЯ
answer = dict(Counter(kin_data.iloc[:, 37]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Рынок медицинских услуг': 35, 'Рынок услуг жилищно-коммунального хозяйства': 30, 'Рынок купли-продажи электрической энергии (мощности) на розничном рынке электрической энергии (мощности)': 4}
# {'Рынок медицинских услуг': 50.72, 'Рынок услуг жилищно-коммунального хозяйства': 43.48, 'Рынок купли-продажи электрической энергии (мощности) на розничном рынке электрической энергии (мощности)': 5.8, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 37])

# %%
# По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности
answer = dict(Counter(kin_data.iloc[:, 38]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Нет': 46, 'Да': 23}
# {'Нет': 66.67, 'Да': 33.33, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 38])

# %%
# СТАЛКИВАЛИСЬ ЛИ ВЫ С ДИСКРИМИНАЦИЕЙ (НЕРАВНЫМ ДОСТУПОМ, УЩЕМЛЕНИЕМ ПРАВ) ВАШЕЙ ОРГАНИЗАЦИИ НА СТАДИИ ОТКРЫТИЯ БИЗНЕСА
answer = dict(Counter(kin_data.iloc[:, 39]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Высокие налоги': 40, 'Нестабильность российского законодательства, регулирующего предпринимательскую деятельность': 16, 'Иные действия/давление со стороны органов власти, препятствующие ведению бизнеса на рынке или входу на рынок новых участников': 13}
# {'Высокие налоги': 57.97, 'Нестабильность российского законодательства, регулирующего предпринимательскую деятельность': 23.19, 'Иные действия/давление со стороны органов власти, препятствующие ведению бизнеса на рынке или входу на рынок новых участников': 18.84, 'Всего': 69}

# %%
#  Как бы Вы охарактеризовали деятельность органов власти на основном для бизнеса
answer = dict(Counter(kin_data.iloc[:, 40]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'нет': 59, 'да': 10}
# {'нет': 85.51, 'да': 14.49, 'Всего': 69}

# %%
# По Вашей оценке, насколько преодолимы административные барьеры для ведения текущей деятельности 
answer = dict(Counter(kin_data.iloc[:, 41]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Скорее удовлетворен': 36, 'Скорее не удовлетворен': 33}
# {'Скорее удовлетворен': 52.17, 'Скорее не удовлетворен': 47.83, 'Всего': 69}

# %%
# По Вашей оценке, как изменился уровень административных барьеров на рынке, основном для бизнеса, 
answer = dict(Counter(kin_data.iloc[:, 42]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Административные барьеры есть, но они преодолимы без существенных затрат': 37, 'Есть барьеры, преодолимые при осуществлении значительных затрат': 32}
# {'Административные барьеры есть, но они преодолимы без существенных затрат': 53.62, 'Есть барьеры, преодолимые при осуществлении значительных затрат': 46.38, 'Всего': 69}

# %%
#  КАК БЫ ВЫ ОХАРАКТЕРИЗОВАЛИ ДЕЯТЕЛЬНОСТЬ ОРГАНОВ ВЛАСТИ НА ОСНОВНОМ ДЛЯ БИЗНЕСА
answer = dict(Counter(kin_data.iloc[:, 43]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Уровень и количество административных барьеров не изменились': 35, 'Ранее административные барьеры отсутствовали, однако сейчас появились': 33, 'Бизнесу стало сложнее преодолевать административные барьеры, чем раньше': 1}
# {'Уровень и количество административных барьеров не изменились': 50.72, 'Ранее административные барьеры отсутствовали, однако сейчас появились': 47.83, 'Бизнесу стало сложнее преодолевать административные барьеры, чем раньше': 1.45, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 43])

# %%
# Оцените характеристики услуг субъектов естественных монополий (срок получения доступа)
st = 44
end = 49

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> КАК БЫ ВЫ ОХАРАКТЕРИЗОВАЛИ ДЕЯТЕЛЬНОСТЬ ОРГАНОВ ВЛАСТИ В ВАШЕЙ СФЕРЕ ДЕЯТЕЛЬНОСТИ?  </td><td> Органы власти  только мешают бизнесу своими действиями </td>  <td> 36 </td><td> Органы власти не предпринимают каких-либо действий, но их участие не обходимо </td>  <td> 21 </td><td> В чем-то органы власти помогают, в чем-то мешают </td>  <td> 9 </td><td> Органы власти помогают бизнесу своими действиями </td>  <td> 3 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (срок получения доступа) [Водоснабжение, водоотведение] </td><td> 2. Скорее удовлетворительно </td>  <td> 35 </td><td> 3. Скорее не удовлетворительно </td>  <td> 22 </td><td> 1. Удовлетворительно </td>  <td> 12 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (срок получения доступа) [Водоочистка] </td><td> 2. Скорее удовлетворительно </td>  <td> 31 </td><td> 3. Скорее не удовлетворительно </td>  <td> 24 </td><td> 1. Удовлетворительно </td>  <td> 1
# ...

# %%
# Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения)
st = 50
end = 55

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики услуг субъектов естественных монополий (срок получения доступа) [Телефонная связь] </td><td> 2. Скорее удовлетворительно </td>  <td> 36 </td><td> 3. Скорее не удовлетворительно </td>  <td> 17 </td><td> 1. Удовлетворительно </td>  <td> 16 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения) [Водоснабжение, водоотведение] </td><td> 2. Скорее удовлетворительно </td>  <td> 38 </td><td> 3. Скорее не удовлетворительно </td>  <td> 20 </td><td> 1. Удовлетворительно </td>  <td> 11 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения) [Водоочистка] </td><td> 2. Скорее удовлетворительно </td>  <td> 40 </td><td> 3. Скорее не удовлетворительно </td>  <td> 16 </td><td> 1. Удовлетворительно </td>  <td> 13 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения) [Газоснабжение] 
# ...

# %%
# Оцените характеристики услуг субъектов естественных монополий (стоимость подключения)
st = 56
end = 61

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения) [Телефонная связь] </td><td> 2. Скорее удовлетворительно </td>  <td> 36 </td><td> 3. Скорее не удовлетворительно </td>  <td> 17 </td><td> 1. Удовлетворительно </td>  <td> 16 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (стоимость подключения) [Водоснабжение, водоотведение] </td><td> 2. Скорее удовлетворительно </td>  <td> 45 </td><td> 3. Скорее не удовлетворительно </td>  <td> 12 </td><td> 1. Удовлетворительно </td>  <td> 12 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (стоимость подключения) [Водоочистка] </td><td> 2. Скорее удовлетворительно </td>  <td> 36 </td><td> 3. Скорее не удовлетворительно </td>  <td> 17 </td><td> 1. Удовлетворительно </td>  <td> 16 </td></tr><tr> <td> Оцените характеристики услуг субъектов естественных монополий (стоимость подключения) [Газоснабжение] </td><td> 2. Скорее у
# ...

# %%
# Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, КОЛЛИЧЕСТВО ПРОЦЕДУР
st = 62
end = 66

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики услуг субъектов естественных монополий (стоимость подключения) [Телефонная связь] </td><td> 2. Скорее удовлетворительно </td>  <td> 43 </td><td> 3. Скорее не удовлетворительно </td>  <td> 14 </td><td> 1. Удовлетворительно </td>  <td> 12 </td></tr><tr> <td>  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  получения [Подключение к электросетям] </td><td> 5-6 </td>  <td> 29 </td><td> 7-8 </td>  <td> 20 </td><td> 3-4 </td>  <td> 18 </td><td> 9 и более </td>  <td> 1 </td><td> 2.0 </td>  <td> 1 </td></tr><tr> <td>  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  получения [Подключение к сетям водоснабжения и водоотведения] </td><td> 5-6 </td>  <td> 32 </td><td> 3-4 </td>  <td> 17 </td><td> 7-8 </td>  <td> 13 </td><td> 9 и более </td>  <t
# ...

# %%
# Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, СРОК ПОДКЛЮЧЕНИЯ
st = 67
end = 71

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td>  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  получения [Получение доступа к земельному участку] </td><td> 5-6 </td>  <td> 28 </td><td> 3-4 </td>  <td> 20 </td><td> 7-8 </td>  <td> 16 </td><td> 2.0 </td>  <td> 4 </td><td> 9 и более </td>  <td> 1 </td></tr><tr> <td>  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки  получения [Подключение к электросетям] </td><td> 51-90 дней </td>  <td> 28 </td><td> 91-150 дней </td>  <td> 23 </td><td> до 50 дней </td>  <td> 16 </td><td> 121-180 дней </td>  <td> 2 </td></tr><tr> <td>  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки  получения [Подключение к сетям водоснабжения и водоотведения] </td><td> 51-90 дней </td>  <td> 35 </td><td> до 50 дней </td>  <td> 18 </td
# ...

# %%
# ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ?
st = 72
end = 81

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td>  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки  получения [Получение доступа к земельному участку] </td><td> 51-90 дней </td>  <td> 30 </td><td> до 50 дней </td>  <td> 21 </td><td> 91-150 дней </td>  <td> 15 </td><td> 121-180 дней </td>  <td> 3 </td></tr><tr> <td> ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ? [Общественная организация по защите прав потребителей] </td><td> Не обращался </td>  <td> 69 </td></tr><tr> <td> ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ? [Роспотребнадзор] </td><td> Обращался, мне помогли </td>  <td> 68 </td><td> Не обращался </td>  <td> 1 </td></tr><tr> <td> ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ? [Росстандарт] </td><td> Обращался, мне помогли </td>  <td> 68 </td><td> Не обращался </td>  <td> 1 </td></tr><tr> <td> ОБРАЩАЛИСЬ 
# ...

# %%
# Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий
st = 82
end = 87

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ? [Другое (указать свой вариант, если ни один из предложенных не подходит)] </td><td> Не обращался </td>  <td> 69 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось количество процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: [Водоснабжение, водоотведение] </td><td> Снизилось </td>  <td> 33 </td><td> Увеличилось </td>  <td> 32 </td><td> Не изменилось </td>  <td> 4 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось количество процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: [Водоочистка] </td><td> Увеличилось </td>  <td> 31 </td><td> Снизилось </td>  <td> 29 </td><td> Не изменилось </td>  <td> 9 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось количество процедур подключения услуг субъектов естественных 
# ...

# %%
#  Оцените, пожалуйста, как изменилось КАЧЕСТВО УСЛУГ субъектов естественных монополий, предоставляемых по месту
st = 88
end = 93

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td>  Оцените, пожалуйста, как изменилось количество процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: [Телефонная связь] </td><td> Снизилось </td>  <td> 33 </td><td> Увеличилось </td>  <td> 30 </td><td> Не изменилось </td>  <td> 6 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет [Водоснабжение, водоотведение] </td><td> Улучшилось </td>  <td> 38 </td><td> Не изменилось </td>  <td> 22 </td><td> Ухудшилось </td>  <td> 9 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет [Водоочистка] </td><td> Улучшилось </td>  <td> 37 </td><td> Не изменилось </td>  <td> 23 </td><td> Ухудшилось </td>  <td> 9 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось кач
# ...

# %%
# Оцените, пожалуйста, как изменился УРОВЕНЬ ЦЕН на услуги субъектов естественных монополий
st = 94
end = 99

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td>  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет [Телефонная связь] </td><td> Не изменилось </td>  <td> 30 </td><td> Улучшилось </td>  <td> 28 </td><td> Ухудшилось </td>  <td> 11 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет [Водоснабжение, водоотведение] </td><td> Увеличился </td>  <td> 69 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет [Водоочистка] </td><td> Увеличился </td>  <td> 69 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет [Газоснабжение] </td><td> Увеличился </td>
# ...

# %%
# С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий?
answer = dict(Counter(kin_data.iloc[:, 100]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Увеличился': 69}
# {'Увеличился': 100.0, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 100])

# %%
# Сталкивались ли Вы с дискриминационными  условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете
answer = dict(Counter(kin_data.iloc[:, 101]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Не сталкивался с подобными проблемами': 41, 'Навязывание дополнительных услуг': 18, 'Затрудняюсь ответить': 10}
# {'Не сталкивался с подобными проблемами': 59.42, 'Навязывание дополнительных услуг': 26.09, 'Затрудняюсь ответить': 14.49, 'Всего': 69}

# %%
make_hist(kin_data.iloc[:, 101])

# %%
# Оцените КАЧЕСТВО УСЛУГ по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
st = 102
end = 105

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Сталкивались ли Вы с дискриминационными  условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? </td><td> Ценовая дискриминация </td>  <td> 36 </td><td> Нет </td>  <td> 17 </td><td> Взимание дополнительной платы </td>  <td> 14 </td><td> Затрудняюсь ответить </td>  <td> 2 </td></tr><tr> <td> Оцените качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Водоснабжение, водоотведение] </td><td> 2. Скорее удовлетворительно </td>  <td> 40 </td><td> 1. Удовлетворительно </td>  <td> 15 </td><td> 3. Скорее не удовлетворительно </td>  <td> 14 </td></tr><tr> <td> Оцените качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Газоснабжение] </td><td> 2. Ск
# ...

# %%
# Оцените СТОИМОСТЬ УСЛУГ по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
st = 105
end = 109

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Электроснабжение] </td><td> 2. Скорее удовлетворительно </td>  <td> 45 </td><td> 1. Удовлетворительно </td>  <td> 16 </td><td> 3. Скорее не удовлетворительно </td>  <td> 8 </td></tr><tr> <td> Оцените качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Теплоснабжение] </td><td> 2. Скорее удовлетворительно </td>  <td> 42 </td><td> 3. Скорее не удовлетворительно </td>  <td> 15 </td><td> 1. Удовлетворительно </td>  <td> 12 </td></tr><tr> <td> Оцените стоимость услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Во
# ...

# %%
# Оцените, пожалуйста, как изменилось качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном
st = 110
end = 113

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените стоимость услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Теплоснабжение] </td><td> 2. Скорее удовлетворительно </td>  <td> 37 </td><td> 3. Скорее не удовлетворительно </td>  <td> 26 </td><td> 1. Удовлетворительно </td>  <td> 6 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Водоснабжение, водоотведение] </td><td> nan </td>  <td> 69 </td></tr><tr> <td>  Оцените, пожалуйста, как изменилось качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Газоснабжение] </td><td> nan </td>  <td> 69 </td></tr><tr>
# ...

# %%
# Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
st = 114
end = 117

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td>  Оцените, пожалуйста, как изменилось качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Теплоснабжение] </td><td> nan </td>  <td> 69 </td></tr><tr> <td>  Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Водоснабжение, водоотведение] </td><td> nan </td>  <td> 69 </td></tr><tr> <td>  Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде, оказываемых ресурсоснабжающими организациями и субъектами естественных монополий [Газоснабжение] </td><td> nan </td>  <td> 69 </td></tr><tr> <td>  Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присо
# ...
