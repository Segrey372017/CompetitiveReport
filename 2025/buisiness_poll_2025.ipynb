# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Загрузка данных опроса

# %%
link = "https://github.com/Segrey372017/CompetitiveReport/raw/refs/heads/main/2025/buisiness_poll_2025.xlsx"

# %%
data = pd.read_excel(link)

# %%
data.head()
# Out:
#            ID       Время создания  \
# 0  1960622057  2025-01-22 22:35:35
# 1  1948245514  2025-01-09 11:51:12
# 2  1949139149  2025-01-10 11:57:11
# 3  1949200440  2025-01-10 13:02:32
# 4  1952521808  2025-01-14 15:54:19
#
#   В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?  \
# 0                        Лухский муниципальный район
# 1                     Заволжский муниципальный район
# 2                              Городской округ Кохма
# 3                            Городской округ Тейково
# 4                         Южский муниципальный район
#
#   Укажите, являетесь ли Вы юридическим лицом или имеете статус индивидуального предпринимателя  \
# 0                                   Юридическое лицо
# 1                                   Юридическое лицо
# 2                                   Юридическое лицо
# 3                      Индивидуальный предпринматель
# 4                                   Юридическое лицо
#
#   В течение какого периода времени Ваш бизнес осуществляет свою деятельность? (пожалуйста, выберите один вариант ответа)  \
# 0                                 От 1 года до 5 лет
# 1                                        Более 5 лет
# 2                                 От 1 года до 5 лет
# 3                                       Менее 1 года
# 4                                 От 1 года до 5 лет
#
#   Какова численность сотрудников вашей организации в настоящее время? (пожалуйста, выберите один вариант ответа)  \
# 0                               От 16 до 100 человек
# 1                               От 16 до 100 человек
# 2                                      До 15 человек
# 3                                      До 15 человек
# 4                                      До 15 человек
#
#   Какую должность Вы занимаете в организации, которую Вы представляете? (пожалуйста, выберите все подходящие варианты ответа)  \
# 0  Руководитель высшего звена (генеральный директ...
# 1  Руководитель среднего звена (руководитель упра...
# 2                   Собственник бизнеса (совладелец)
# 3                   Собственник бизнеса (совладелец)
# 4  Руководитель высшего звена (генеральный директ...
#
#   Какова примерная величина годового оборота бизнеса, который Вы представляете? (пожалуйста, выберите один вариант ответа)  \
# 0                                 До 120 млн. рублей
# 1              От 120 млн. рублей до 800 млн. рублей
# 2                                 До 120 млн. рублей
# 3                                 До 120 млн. рублей
# 4                                 До 120 млн. рублей
#
#   К какой сфере экономической деятельности относится Ваш бизнес, который Вы представляете? (пожалуйста, отметьте основной вид деятельности бизнеса, который Вы представляете)  \
# 0    Рынок услуг по ремонту автотранспортных средств
# 1                        Рынок легкой промышленности
# 2                        Рынок легкой промышленности
# 3                Рынок услуг дошкольного образования
# 4  Рынок оказания услуг по перевозке пассажиров а...
#
#   Основной продукцией (товаром, работой, услугой) бизнеса, который Вы представляете, является (пожалуйста, выберите один вариант ответа)  \
# 0                                             Услуги
# 1                                 Конечная продукция
# 2                                 Конечная продукция
# 3                                             Услуги
# 4                                             Услуги
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Требование заказа необходимых работ у подконтрольных коммерческих структур  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Не сталкивался с подобными проблемами  \
# 0              Не сталкивался с подобными проблемами
# 1              Не сталкивался с подобными проблемами
# 2              Не сталкивался с подобными проблемами
# 3                                                NaN
# 4                                                NaN
#
#   С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Затрудняюсь ответить  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                               Затрудняюсь ответить
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Отсутствие организации и проведения торгов на ...
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Ценовая дискриминация  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                              Ценовая дискриминация
# 4                                                NaN
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Не сталкивался  \
# 0                                     Не сталкивался
# 1                                     Не сталкивался
# 2                                     Не сталкивался
# 3                                                NaN
# 4                                                NaN
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Затрудняюсь ответить  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Со всеми перечисленными дискриминационными условиями
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# ### Список вопросов (колонок)

# %%
for i in range(len(data.columns)):
    print(i,'. ',data.columns[i])
# Out:
# 0 .  ID
# 1 .  Время создания
# 2 .  В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?
# 3 .  Укажите, являетесь ли Вы юридическим лицом или имеете статус индивидуального предпринимателя
# 4 .  В течение какого периода времени Ваш бизнес осуществляет свою деятельность? (пожалуйста, выберите один вариант ответа)
# 5 .  Какова численность сотрудников вашей организации в настоящее время? (пожалуйста, выберите один вариант ответа)
# 6 .  Какую должность Вы занимаете в организации, которую Вы представляете? (пожалуйста, выберите все подходящие варианты ответа)
# 7 .  Какова примерная величина годового оборота бизнеса, который Вы представляете? (пожалуйста, выберите один вариант ответа)
# 8 .  К какой сфере экономической деятельности относится Ваш бизнес, который Вы представляете? (пожалуйста, отметьте основной вид деятельности бизнеса, который Вы представляете)
# 9 .  Основной продукцией (товаром, работой, услугой) бизнеса, который Вы представляете, является (пожалуйста, выберите один вариант ответа)
# 10 .  Какую именно продукцию (товары, работы, услуги) реализует бизнес, который Вы представляете?
# Какой географический рынок (рынки) является основным (рынок, на котором регулярно реализуется наибольшая доля продукции (товара, работы, услуги) для бизнеса, который Вы представляете? (пожалуйста, укажите один наиболее подходящий вариант ответа)
# 11 .  Выберите утверждение, наиболее точно характеризующее условия ведения бизнеса, который Вы представляете (пожалуйста, укажите один наиболее подходящий вариант ответа):
# 12 .  Укажите, какие меры по повышению конкурентоспособности продукции, работ, услуг, которые производит или предоставляет Ваш бизнес, Вы предпринимали за последние 3 года
# 13 .  Оцените примерное количество конкурентов бизнеса, который Вы представляете, предлагающих аналогичную продукцию (товар, работу, услугу) или ее заменители, на основном для него рынке (пожалуйста, выберите один вариант ответа)
# 14 .  Как изменилось число конкурентов бизнеса, который Вы представляете, на основном рынке товаров и услуг за последние 3 года? (пожалуйста, выберите один вариант ответа):
# 15 .  Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Уровень доступности
# 16 .  Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Уровень понятности
# 17 .  Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Удобство получения
# 18 .  Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о нормативной базе, связанной с внедрением Стандарта в регионе
# 19 .  Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о перечне товарных рынков для содействия развитию конкуренции в регионе
# 20 .  Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Предоставление возможности прохождения электронных анкет, связанных с оценкой удовлетворенности предпринимателей и потребителей состоянием конкурентной среды региона
# 21 .  Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Обеспечение доступности "дорожной карты" региона
# 22 .  Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о проведенных обучающих мероприятиях для органов местного самоуправления региона
# 23 .  Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о проведенных мониторингах в регионе и сформированном ежегодном докладе
# 24 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на сайте уполномоченного органа в информационно-телекоммуникационной сети "Интернет"
# 25 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на интернет-портале об инвестиционной деятельности в субъекте Российской Федерации
# 26 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на официальном сайте ФАС России в информационно-телекоммуникационной сети "Интернет"
# 27 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Информация, размещенная на официальных сайтах других исполнительных органов государственной власти субъекта Российской Федерации и органов местного самоуправления в информационно-телекоммуникационной сети "Интернет"
# 28 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Телевидение
# 29 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Печатные средства массовой информации
# 30 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Радио
# 31 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Специальные блоги, порталы и прочие электронные ресурсы
# 32 .  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Другое (укажите, пожалуйста)
# 33 .  Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает представляемый Вами бизнес для производства и реализации собственной продукции (если применимо), а также Вашу удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги) (пожалуйста, выберите один вариант ответа для каждой строки) / Число поставщиков основного закупаемого товара (работы, услуги)
# 34 .  Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает представляемый Вами бизнес для производства и реализации собственной продукции (если применимо), а также Вашу удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги) (пожалуйста, выберите один вариант ответа для каждой строки) / Удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги)
# 35 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Сложность получения доступа к земельным участкам
# 36 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Нестабильность российского законодательства, регулирующего предпринимательскую деятельность
# 37 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Коррупция (включая взятки, дискриминацию и предоставление преференций отдельным участникам на заведомо неравных условиях)
# 38 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Сложность/затянутость процедуры получения лицензий
# 39 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Высокие налоги
# 40 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Необходимость установления партнерских отношений с органами власти
# 41 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Ограничение/сложность доступа к закупкам компаний с государственным участием и субъектов естественных монополий
# 42 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Ограничение/сложность доступа к поставкам товаров, оказанию услуг и выполнению работ в рамках государственных закупок
# 43 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Ограничение органами власти инициатив по организации совместной деятельности малых предприятий (например, в части создания совместных предприятий, кооперативов и др.)
# 44 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Иные действия/давление со стороны органов власти, препятствующие ведению бизнеса на рынке или входу на рынок новых участников
# 45 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Силовое давление со стороны правоохранительных органов (угрозы, вымогательства и т.д.)
# 46 .  По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Нет ограничений
# 47 .  Как бы Вы охарактеризовали деятельность органов власти на основном для бизнеса, который Вы представляете, рынке? (пожалуйста, укажите один наиболее подходящий вариант ответа):
# 48 .  По Вашей оценке, насколько преодолимы административные барьеры для ведения текущей деятельности и открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, укажите один наиболее подходящий вариант ответа):
# 49 .  По Вашей оценке, как изменился уровень административных барьеров на рынке, основном для бизнеса, который Вы представляете, в течение последних 3 лет?
# 50 .  Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение
# 51 .  Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка
# 52 .  Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение
# 53 .  Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Электроснабжение
# 54 .  Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Теплоснабжение
# 55 .  Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Телефонная связь
# 56 .  Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение
# 57 .  Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка
# 58 .  Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение
# 59 .  Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Электроснабжение
# 60 .  Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Теплоснабжение
# 61 .  Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Телефонная связь
# 62 .  Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение
# 63 .  Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка
# 64 .  Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение
# 65 .  Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Электроснабжение
# 66 .  Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Теплоснабжение
# 67 .  Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Телефонная связь
# 68 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к электросетям
# 69 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к сетям водоснабжения и водоотведения
# 70 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к тепловым сетям
# 71 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к телефонной сети
# 72 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Получение доступа к земельному участку
# 73 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к электросетям
# 74 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к сетям водоснабжения и водоотведения
# 75 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к тепловым сетям
# 76 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к телефонной сети
# 77 .  Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Получение доступа к земельному участку
# 78 .  Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение
# 79 .  Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка
# 80 .  Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение
# 81 .  Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Электроснабжение
# 82 .  Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Теплоснабжение
# 83 .  Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Телефонная связь
# 84 .  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение
# 85 .  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка
# 86 .  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение
# 87 .  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Электроснабжение
# 88 .  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Теплоснабжение
# 89 .  Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Телефонная связь
# 90 .  Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение
# 91 .  Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка
# 92 .  Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение
# 93 .  Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Электроснабжение
# 94 .  Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Теплоснабжение
# 95 .  Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Телефонная связь
# 96 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Взимание дополнительной платы
# 97 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Навязывание дополнительных услуг
# 98 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Отказ в установке приборов учета
# 99 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Проблемы с заменой приборов учета
# 100 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Требование заказа необходимых работ у подконтрольных коммерческих структур
# 101 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Не сталкивался с подобными проблемами
# 102 .  С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Затрудняюсь ответить
# 103 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их
# 104 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Ценовая дискриминация
# 105 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки
# 106 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности
# 107 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Не сталкивался
# 108 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Затрудняюсь ответить
# 109 .  Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Со всеми перечисленными дискриминационными условиями

# %%
def make_hist(d_info):
    "Выодит гистограму по полученным данным"
    plt.figure(figsize= (8,6))
    sns.histplot(d_info)
    plt.xticks(rotation = 90)
    plt.ylabel('Число опрошенных')
    plt.show()
    return

# %%
def calc_percent(cnt, r = 2):
    """ Считает процентное соотношение числа опрошенных,всего опрошенных 100%
        r - окгугление до r знаков после запятой
    """
    s = sum(cnt.values())
    p_cnt = dict()

    for key in cnt.keys():
        p_cnt[key] = round(cnt[key] / s * 100, r)

    p_cnt['Всего'] = s
    return p_cnt

# %%
from collections import Counter
cities = dict(Counter(data[data.columns[2]]).most_common())
print(cities)
print(calc_percent(cities))
# Out:
# {'Заволжский муниципальный район': 34, 'Пестяковский муниципальный район': 34, 'Лухский муниципальный район': 33, 'Кинешемский муниципальный район': 33, 'Городской округ Кинешма': 33, 'Городской округ Вичуга': 32, 'Южский муниципальный район': 31, 'Вичугский муниципальный район': 31, 'Комсомольский муниципальный район': 31, 'Городской округ Кохма': 30, 'Городской округ Тейково': 30, 'Палехский муниципальный район': 30, 'Родниковский муниципальный район': 30, 'Приволжский муниципальный район': 30, 'Гаврилово-Посадский муниципальный район': 30, 'Лежневский муниципальный район': 30, 'Городской округ Шуя': 26, 'Ивановский муниципальный район': 25, 'Шуйский муниципальный район': 25, 'Верхнеландеховский муниципальный район': 24, 'Савинский муниципальный район': 23, 'Тейковский муниципальный район': 22, 'Городской округ Иваново': 22, 'Ильинский муниципальный район': 21, 'Пучежский муниципальный район': 19, 'Фурмановский муниципальный район': 18, 'Юрьевецкий муниципальный район': 14}
# {'Заволжский муниципальный район': 4.59, 'Пестяковский муниципальный район': 4.59, 'Лухский муниципальный район': 4.45, 'Кинешемский муниципальный район': 4.45, 'Городской округ Кинешма': 4.45, 'Городской округ Вичуга': 4.32, 'Южский муниципальный район': 4.18, 'Вичугский муниципальный район': 4.18, 'Комсомольский муниципальный район': 4.18, 'Городской округ Кохма': 4.05, 'Городской округ Тейково': 4.05, 'Палехский муниципальный район': 4.05, 'Родниковский муниципальный район': 4.05, 'Приволжский муниципальный район': 4.05, 'Гаврилово-Посадский муниципальный район': 4.05, 'Лежневский муниципальный район': 4.05, 'Городской округ Шуя': 3.51, 'Ивановский муниципальный район': 3.37, 'Шуйский муниципальный район': 3.37, 'Верхнеландеховский муниципальный район': 3.24, 'Савинский муниципальный район': 3.1, 'Тейковский муниципальный район': 2.97, 'Городской округ Иваново': 2.97, 'Ильинский муниципальный район': 2.83, 'Пучежский муниципальный район': 2.56, 'Фурмановский муниципальный район': 2.43, 'Юрьевецкий муниципальный район': 1.89, 'Всего': 741}

# %%
data.iloc[:, 2].value_counts()
# Out:
# В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?
# Пестяковский муниципальный район           34
# Заволжский муниципальный район             34
# Городской округ Кинешма                    33
# Кинешемский муниципальный район            33
# Лухский муниципальный район                33
# Городской округ Вичуга                     32
# Вичугский муниципальный район              31
# Комсомольский муниципальный район          31
# Южский муниципальный район                 31
# Родниковский муниципальный район           30
# Лежневский муниципальный район             30
# Городской округ Кохма                      30
# Гаврилово-Посадский муниципальный район    30
# Городской округ Тейково                    30
# Приволжский муниципальный район            30
# Палехский муниципальный район              30
# Городской округ Шуя                        26
# Шуйский муниципальный район                25
# Ивановский муниципальный район             25
# Верхнеландеховский муниципальный район     24
# Савинский муниципальный район              23
# Городской округ Иваново                    22
# Тейковский муниципальный район             22
# Ильинский муниципальный район              21
# Пучежский муниципальный район              19
# Фурмановский муниципальный район           18
# Юрьевецкий муниципальный район             14
# Name: count, dtype: int64

# %%
make_hist(data.iloc[:, 2])

# %% [markdown]
# # Выбор данных по Кинешме

# %%
kin_index = data.index[data[data.columns[2]].values=='Городской округ Кинешма']
kin_data = data.iloc[kin_index,:]
del data

# %%
kin_data.head()
# Out:
#              ID       Время создания  \
# 178  1951253035  2025-01-13 11:25:53
# 457  1954633752  2025-01-16 17:02:12
# 517  1955559508  2025-01-17 16:15:22
# 518  1955575041  2025-01-17 16:31:41
# 519  1955577354  2025-01-17 16:34:12
#
#     В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?  \
# 178                            Городской округ Кинешма
# 457                            Городской округ Кинешма
# 517                            Городской округ Кинешма
# 518                            Городской округ Кинешма
# 519                            Городской округ Кинешма
#
#     Укажите, являетесь ли Вы юридическим лицом или имеете статус индивидуального предпринимателя  \
# 178                      Индивидуальный предпринматель
# 457                      Индивидуальный предпринматель
# 517                      Индивидуальный предпринматель
# 518                      Индивидуальный предпринматель
# 519                                   Юридическое лицо
#
#     В течение какого периода времени Ваш бизнес осуществляет свою деятельность? (пожалуйста, выберите один вариант ответа)  \
# 178                                        Более 5 лет
# 457                                       Менее 1 года
# 517                                 От 1 года до 5 лет
# 518                                        Более 5 лет
# 519                                        Более 5 лет
#
#     Какова численность сотрудников вашей организации в настоящее время? (пожалуйста, выберите один вариант ответа)  \
# 178                                      До 15 человек
# 457                                      До 15 человек
# 517                                      До 15 человек
# 518                                      До 15 человек
# 519                               От 16 до 100 человек
#
#     Какую должность Вы занимаете в организации, которую Вы представляете? (пожалуйста, выберите все подходящие варианты ответа)  \
# 178                   Собственник бизнеса (совладелец)
# 457  Руководитель среднего звена (руководитель упра...
# 517                   Собственник бизнеса (совладелец)
# 518                   Собственник бизнеса (совладелец)
# 519  Руководитель высшего звена (генеральный директ...
#
#     Какова примерная величина годового оборота бизнеса, который Вы представляете? (пожалуйста, выберите один вариант ответа)  \
# 178                                 До 120 млн. рублей
# 457                                 До 120 млн. рублей
# 517                                 До 120 млн. рублей
# 518                                 До 120 млн. рублей
# 519                                 До 120 млн. рублей
#
#     К какой сфере экономической деятельности относится Ваш бизнес, который Вы представляете? (пожалуйста, отметьте основной вид деятельности бизнеса, который Вы представляете)  \
# 178                             Рынок социальных услуг
# 457  Рынок услуг связи, в том числе услуг по предос...
# 517                            Рынок медицинских услуг
# 518                        Рынок легкой промышленности
# 519    Рынок услуг по ремонту автотранспортных средств
#
#     Основной продукцией (товаром, работой, услугой) бизнеса, который Вы представляете, является (пожалуйста, выберите один вариант ответа)  \
# 178  Бизнес осуществляет торговлю или дистрибуцию т...
# 457                                             Услуги
# 517                                             Услуги
# 518                                 Конечная продукция
# 519                                             Услуги
#
#      ...  \
# 178  ...
# 457  ...
# 517  ...
# 518  ...
# 519  ...
#
#     С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Требование заказа необходимых работ у подконтрольных коммерческих структур  \
# 178                                                NaN
# 457                                                NaN
# 517                                                NaN
# 518  Требование заказа необходимых работ у подконтр...
# 519                                                NaN
#
#     С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Не сталкивался с подобными проблемами  \
# 178                                                NaN
# 457              Не сталкивался с подобными проблемами
# 517                                                NaN
# 518                                                NaN
# 519              Не сталкивался с подобными проблемами
#
#     С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Затрудняюсь ответить  \
# 178                               Затрудняюсь ответить
# 457                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их  \
# 178                                                NaN
# 457                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Ценовая дискриминация  \
# 178                              Ценовая дискриминация
# 457                                                NaN
# 517                              Ценовая дискриминация
# 518                              Ценовая дискриминация
# 519                                                NaN
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки  \
# 178                                                NaN
# 457  Продажа товара только в определенном ассортиме...
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности  \
# 178                                                NaN
# 457                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519  Акты органов государственной власти субъектов ...
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Не сталкивался  \
# 178                                                NaN
# 457                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Затрудняюсь ответить  \
# 178                                                NaN
# 457                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
#     Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Со всеми перечисленными дискриминационными условиями
# 178                                                NaN
# 457                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# ## Общие вопросы

# %%
# Форма осуществления деятельности
form = dict(Counter(kin_data.iloc[:, 3]).most_common())
print(form)
print(calc_percent(form))
del form
# Out:
# {'Индивидуальный предпринматель': 21, 'Юридическое лицо': 12}
# {'Индивидуальный предпринматель': 63.64, 'Юридическое лицо': 36.36, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 3])

# %%
#  В течении какого периода времени Ваш бизнес осуществляет свою деятельность?
b_age = dict(Counter(kin_data.iloc[:, 4]).most_common())
print(b_age)
print(calc_percent(b_age))
del b_age
# Out:
# {'Более 5 лет': 21, 'От 1 года до 5 лет': 11, 'Менее 1 года': 1}
# {'Более 5 лет': 63.64, 'От 1 года до 5 лет': 33.33, 'Менее 1 года': 3.03, 'Всего': 33}

# %%
# Какую должность Вы занимаете в организации, которую Вы представляете?
employee = dict(Counter(kin_data.iloc[:, 6]).most_common())
print(employee)
print(calc_percent(employee))
del employee
# Out:
# {'Собственник бизнеса (совладелец)': 27, 'Руководитель высшего звена (генеральный директор, заместитель генерального директора или иная аналогичная позиция)': 5, 'Руководитель среднего звена (руководитель управления/подразделения/отдела)': 1}
# {'Собственник бизнеса (совладелец)': 81.82, 'Руководитель высшего звена (генеральный директор, заместитель генерального директора или иная аналогичная позиция)': 15.15, 'Руководитель среднего звена (руководитель управления/подразделения/отдела)': 3.03, 'Всего': 33}

# %%
# Какова численность сотрудников Вашей организации в настоящее время?
employee = dict(Counter(kin_data.iloc[:, 5]).most_common())
print(employee)
print(calc_percent(employee))
del employee
# Out:
# {'До 15 человек': 28, 'От 16 до 100 человек': 5}
# {'До 15 человек': 84.85, 'От 16 до 100 человек': 15.15, 'Всего': 33}

# %%
# Какова примерная величина годового оборота бизнеса, который вы представляете?
turnover = dict(Counter(kin_data.iloc[:, 7]).most_common())
print(turnover)
print(calc_percent(turnover))
del turnover
# Out:
# {'До 120 млн. рублей': 33}
# {'До 120 млн. рублей': 100.0, 'Всего': 33}

# %%
# К какой социально-значимой сфере экономической деятельности относится деятельность бизнеса, которой вы представляете?
otrasl = dict(Counter(kin_data.iloc[:, 8]).most_common())
print(otrasl)
print(calc_percent(otrasl))
del otrasl
# Out:
# {'Рынок легкой промышленности': 12, 'Рынок услуг по ремонту автотранспортных средств': 10, 'Рынок строительства объектов капитального строительства, за исключением жилищного и дорожного строительства': 6, 'Сфера наружной рекламы': 2, 'Рынок социальных услуг': 1, 'Рынок услуг связи, в том числе услуг по предоставлению широкополосного доступа к информационно-телекоммуникационной сети "Интернет"': 1, 'Рынок медицинских услуг': 1}
# {'Рынок легкой промышленности': 36.36, 'Рынок услуг по ремонту автотранспортных средств': 30.3, 'Рынок строительства объектов капитального строительства, за исключением жилищного и дорожного строительства': 18.18, 'Сфера наружной рекламы': 6.06, 'Рынок социальных услуг': 3.03, 'Рынок услуг связи, в том числе услуг по предоставлению широкополосного доступа к информационно-телекоммуникационной сети "Интернет"': 3.03, 'Рынок медицинских услуг': 3.03, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 8])

# %%
# Основной продукцией (товаром, работой, услугой) бизнеса, который Вы представляете, является (пожалуйста, выберите один вариант ответа)
okved = dict(Counter(kin_data.iloc[:, 9]).most_common())
print(okved)
print(calc_percent(okved))
del okved
# Out:
# {'Услуги': 22, 'Конечная продукция': 6, 'Компоненты для производства конечной продукции': 4, 'Бизнес осуществляет торговлю или дистрибуцию товаров и услуг, произведенных другими компаниями': 1}
# {'Услуги': 66.67, 'Конечная продукция': 18.18, 'Компоненты для производства конечной продукции': 12.12, 'Бизнес осуществляет торговлю или дистрибуцию товаров и услуг, произведенных другими компаниями': 3.03, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 9])

# %%
# Какой географический рынок (рынки) является основным (рынок, на котором регулярно реализуется наибольшая доля продукции (товара, работы, услуги) для бизнеса, который Вы представляете?
product = dict(Counter(kin_data.iloc[:, 10]).most_common())
print(product)
print(calc_percent(product))
del product
# Out:
# {'Рынок нескольких субъектов Российской Федерации': 17, 'Региональный рынок': 11, 'Локальный рынок': 5}
# {'Рынок нескольких субъектов Российской Федерации': 51.52, 'Региональный рынок': 33.33, 'Локальный рынок': 15.15, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 10])

# %%
# Какую именно продукцию (товары, работы, услуги) реализует бизнес, который вы представляете?
"""
product = dict(Counter(kin_data.iloc[:, 10]).most_common())
print(product)
print(calc_percent(product))
del product
"""
# Out:
# '\nproduct = dict(Counter(kin_data.iloc[:, 10]).most_common())\nprint(product)\nprint(calc_percent(product))\ndel product\n'

# %%
#make_hist(kin_data.iloc[:, 10])

# %% [markdown]
# ## Конкурентоспособность бизнеса

# %% [markdown]
# ### Укажите, какие меры по повышению конкурентоспособности продукции, работ, услуг

# %%
# Укажите, какие меры по повышению конкурентоспособности продукции, работ, услуг, которые производит или предоставляет Ваш бизнес

mesures = dict(Counter(kin_data.iloc[:, 12]).most_common())
print(mesures)
print(calc_percent(mesures))
del mesures
# Out:
# {'Обучение и переподготовка персонала': 18, 'Разработка новых модификаций и форм производимой продукции, расширение ассортимента': 9, 'Приобретение технического оборудования': 5, 'Новые способы продвижения продукции (маркетинговые стратегии)': 1}
# {'Обучение и переподготовка персонала': 54.55, 'Разработка новых модификаций и форм производимой продукции, расширение ассортимента': 27.27, 'Приобретение технического оборудования': 15.15, 'Новые способы продвижения продукции (маркетинговые стратегии)': 3.03, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 12])

# %%
# Какой географический рынок (рынки) является основным* для бизнеса
"""
area = dict(Counter(kin_data.iloc[:, 12]).most_common())
print(area)
print(calc_percent(area))
del area
"""
# Out:
# '\narea = dict(Counter(kin_data.iloc[:, 12]).most_common())\nprint(area)\nprint(calc_percent(area))\ndel area\n'

# %% [markdown]
# ### Выберите утверждение, наиболее точно характеризующее условия ведения бизнеса

# %%
# Выберите утверждение, наиболее точно характеризующее условия ведения бизнеса, который Вы представляете (пожалуйста, укажите один наиболее подходящий вариант ответа):
answer = dict(Counter(kin_data.iloc[:, 11]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно (раз в год или чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - умеренная конкуренция': 17, 'Для сохранения рыночной позиции нашего бизнеса время от времени (раз в 2 - 3 года) может потребоваться реализация мер по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - слабая конкуренция': 9, 'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно (раз в год или чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное), а также время от времени (раз в 2 - 3 года) применять новые способы ее повышения, не используемые компанией ранее, - высокая конкуренция': 5, 'Для сохранения рыночной позиции нашего бизнеса необходимо постоянно (раз в год и чаще) применять новые способы повышения конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное), не используемые компанией ранее, - очень высокая конкуренция': 1, 'Для сохранения рыночной позиции нашего бизнеса нет необходимости реализовывать какие-либо меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - нет конкуренции': 1}
# {'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно (раз в год или чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - умеренная конкуренция': 51.52, 'Для сохранения рыночной позиции нашего бизнеса время от времени (раз в 2 - 3 года) может потребоваться реализация мер по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - слабая конкуренция': 27.27, 'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно (раз в год или чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное), а также время от времени (раз в 2 - 3 года) применять новые способы ее повышения, не используемые компанией ранее, - высокая конкуренция': 15.15, 'Для сохранения рыночной позиции нашего бизнеса необходимо постоянно (раз в год и чаще) применять новые способы повышения конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное), не используемые компанией ранее, - очень высокая конкуренция': 3.03, 'Для сохранения рыночной позиции нашего бизнеса нет необходимости реализовывать какие-либо меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - нет конкуренции': 3.03, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 11])

# %% [markdown]
# ### Оцените примерное количество конкурентов бизнеса

# %%
# Оцените примерное количество конкурентов бизнеса, который Вы представляете, предлагающих аналогичную продукцию (товар, работу, услугу) или ее заменители,
answer = dict(Counter(kin_data.iloc[:, 13]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Большое число конкурентов': 13, 'От 4 до 8 конкурентов': 13, 'От 1 до 3 конкурентов': 7}
# {'Большое число конкурентов': 39.39, 'От 4 до 8 конкурентов': 39.39, 'От 1 до 3 конкурентов': 21.21, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 13])

# %% [markdown]
# ### Как изменилось число конкурентов бизнеса

# %%
# Как изменилось число конкурентов бизнеса, который Вы представляете, на основном рынке товаров и услуг за последние 3 года?
answer = dict(Counter(kin_data.iloc[:, 14]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Сократилось на 1 - 3 конкурента': 15, 'Увеличилось на 1 - 3 конкурента': 9, 'Сократилось более чем на 4 конкурента': 8, 'Увеличилось более чем на 4 конкурента': 1}
# {'Сократилось на 1 - 3 конкурента': 45.45, 'Увеличилось на 1 - 3 конкурента': 27.27, 'Сократилось более чем на 4 конкурента': 24.24, 'Увеличилось более чем на 4 конкурента': 3.03, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 14])

# %% [markdown]
# ## Доступность информации

# %% [markdown]
# ### Оцените качество официальной информации о состоянии конкурентной среды

# %%
# Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг ивановской области
from IPython.display import HTML, display
st = 15
end = 17

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Уровень доступности </td><td> Скорее удовлетворительно </td>  <td> 17 </td><td> Удовлетворительно </td>  <td> 8 </td><td> Скорее неудовлетворительно </td>  <td> 7 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td></tr><tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Уровень понятности </td><td> Скорее удовлетворительно </td>  <td> 14 </td><td> Скорее неудовлетворительно </td>  <td> 10 </td><td> Удовлетворительно </td>  <td> 8 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td></tr><tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Удобство получения </td><td> Скорее удовлетворительно </td>  <td> 21 </td><td> Скорее неудовлетворительно </td>  <td> 6 </td><td> Удовлетворительно </td>  <td> 5 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td></tr></table>

# %%
def fill_freq_mat(data, cats, columns):
    N = data.shape[0]
    M = data.shape[1]

    freq_mat = {}
    for col in cats:  # создаем матрицу для подсчета категорий
        freq_mat[col] = np.zeros(len(columns))

    for i in range(N):
        for j in range(M):
            freq_mat[data.iloc[i,j]][j] += 1

    return pd.DataFrame(data = freq_mat, index = columns)

# %%
# Тепловая карта
cat = ["Удовлетворительно", "Скорее удовлетворительно", "Скорее неудовлетворительно", "Затрудняюсь ответить/мне ничего не известно о такой информации"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Оцените полноту информации

# %%
# Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации
st = 18
end = 23

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о нормативной базе, связанной с внедрением Стандарта в регионе </td><td> Скорее удовлетворительно </td>  <td> 16 </td><td> Скорее неудовлетворительно </td>  <td> 13 </td><td> Неудовлетворительно </td>  <td> 2 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td><td> Удовлетворительно </td>  <td> 1 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о перечне товарных рынков для содействия развитию конкуренции в регионе </td><td> Скорее удовлетворительно </td>  <td> 18 </td><td> Скорее неудовлетворительно </td>  <td> 10 </td><td> Неудовлетворительно </td>  <td> 3 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td><td> Удовлетворительно </td>  <td> 1 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Предоставление возможности прохождения электронных анкет, связанных с оценкой удовлетворенности предпринимателей и потребителей состоянием конкурентной среды региона </td><td> Скорее неудовлетворительно </td>  <td> 15 </td><td> Скорее удовлетворительно </td>  <td> 12 </td><td> Неудовлетворительно </td>  <td> 4 </td><td> Удовлетворительно </td>  <td> 2 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Обеспечение доступности "дорожной карты" региона </td><td> Скорее неудовлетворительно </td>  <td> 17 </td><td> Скорее удовлетворительно </td>  <td> 13 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td><td> Удовлетворительно </td>  <td> 1 </td><td> Неудовлетворительно </td>  <td> 1 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о проведенных обучающих мероприятиях для органов местного самоуправления региона </td><td> Скорее удовлетворительно </td>  <td> 17 </td><td> Скорее неудовлетворительно </td>  <td> 14 </td><td> Неудовлетворительно </td>  <td> 1 </td><td> Удовлетворительно </td>  <td> 1 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации  ...

# %%
# Тепловая карта
cat = ["Удовлетворительно", "Скорее удовлетворительно", "Скорее неудовлетворительно", "Неудовлетворительно", "Затрудняюсь ответить/мне ничего не известно о такой информации"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Источники информации о конкурентной среде

# %%
#  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации
st = 24
end = 32

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на сайте уполномоченного органа в информационно-телекоммуникационной сети "Интернет" </td><td> Предпочитаю пользоваться </td>  <td> 22 </td><td> Доверяю больше всего </td>  <td> 11 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на интернет-портале об инвестиционной деятельности в субъекте Российской Федерации </td><td> Предпочитаю пользоваться </td>  <td> 20 </td><td> Доверяю больше всего </td>  <td> 13 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на официальном сайте ФАС России в информационно-телекоммуникационной сети "Интернет" </td><td> Предпочитаю пользоваться </td>  <td> 19 </td><td> Доверяю больше всего </td>  <td> 14 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Информация, размещенная на официальных сайтах других исполнительных органов государственной власти субъекта Российской Федерации и органов местного самоуправления в информационно-телекоммуникационной сети "Интернет" </td><td> Предпочитаю пользоваться </td>  <td> 17 </td><td> Доверяю больше всего </td>  <td> 16 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Телевидение </td><td> Предпочитаю пользоваться </td>  <td> 25 </td><td> Доверяю больше всего </td>  <td> 8 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Печатные средства массовой информации </td><td> Предпочитаю пользоваться </td>  <td> 21 </td><td> Доверяю больше всего </td>  <td> 12 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Радио </td><td> Предпочитаю пользоваться </td>  <td> 18 </td><td> Доверяю больше всего </td>  <td> 15 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Специальные блоги, порталы и прочие электронные ресурсы </td><td> Предпочитаю пользоваться </td>  <td> 20 </td><td> Доверяю больше всего </td>  <td> 13 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Другое (укажите, пожалуйста) </td><td> Предпочитаю пользоваться </td>  <td> 20 </td><td> Доверяю больше всего </td>  <td> 13 </td></tr></table>

# %%
# Тепловая карта
cat = ["Доверяю больше всего", "Предпочитаю пользоваться"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Внешние условия конкуренции

# %% [markdown]
# ### Пожалуйста, оцените примерное число поставщиков основного закупаемого товара

# %%
# Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает
st = 33
end = 34

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает представляемый Вами бизнес для производства и реализации собственной продукции (если применимо), а также Вашу удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги) (пожалуйста, выберите один вариант ответа для каждой строки) / Число поставщиков основного закупаемого товара (работы, услуги) </td><td> 4 и более поставщика/скорее удовлетворительно </td>  <td> 15 </td><td> 2 - 3 поставщика/скорее неудовлетворительно </td>  <td> 11 </td><td> Большое число поставщиков/удовлетворительно </td>  <td> 4 </td><td> Единственный поставщик/неудовлетворительно </td>  <td> 3 </td></tr><tr> <td> Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает представляемый Вами бизнес для производства и реализации собственной продукции (если применимо), а также Вашу удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги) (пожалуйста, выберите один вариант ответа для каждой строки) / Удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги) </td><td> 4 и более поставщика/скорее удовлетворительно </td>  <td> 17 </td><td> 2 - 3 поставщика/скорее неудовлетворительно </td>  <td> 11 </td><td> Единственный поставщик/неудовлетворительно </td>  <td> 4 </td><td> Большое число поставщиков/удовлетворительно </td>  <td> 1 </td></tr></table>

# %%
# ПОЖАЛУЙСТА, УКАЖИТЕ НАИМЕНОВАНИЕ ОСНОВНОГО ЗАКУПАЕМОГО ТОВАРА (РАБОТЫ, УСЛУГИ)
"""
answer = dict(Counter(kin_data.iloc[:, 35]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 35]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 35])

# %%
# Пожалуйста, укажите наименование товаров, работ, услуг, закупаемых представляемым вами бизнесом для производства
"""
answer = dict(Counter(kin_data.iloc[:, 36]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 36]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 36])

# %%
# КАКОЙ ОТРАСЛЕВОЙ РЫНОК В ВАШЕМ РАЙОНЕ/ГОРОДСКОМ ОКРУГЕ ВЫ СЧИТАЕТЕ ПРИОРИТЕТНЫМИ И СОЦИАЛЬНО-ЗНАЧИМЫМИ
"""
answer = dict(Counter(kin_data.iloc[:, 37]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 37]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 37])

# %%
# СЧИТАЕТЕ ЛИ ВЫ, ЧТО КОНКУРЕНЦИЯ НА ВАШЕМ ОТРАСЛЕВОМ РЫНКЕ В ВАШЕМ РАЙОНЕ/ГОРОДСКОМ ОКРУГЕ ИМЕЕТ ВЫСОКИЙ УРОВЕНЬ РАЗВИТИЯ
"""
answer = dict(Counter(kin_data.iloc[:, 38]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 38]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 38])

# %% [markdown]
# ## Административные барьеры, естественные монополии

# %% [markdown]
# ### Какие из перечисленных административных барьеров являются наиболее существенными

# %%
# По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности
st = 35
end = 46

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Сложность получения доступа к земельным участкам </td><td> nan </td>  <td> 31 </td><td> Сложность получения доступа к земельным участкам </td>  <td> 2 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Нестабильность российского законодательства, регулирующего предпринимательскую деятельность </td><td> nan </td>  <td> 27 </td><td> Нестабильность российского законодательства, регулирующего предпринимательскую деятельность </td>  <td> 6 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Коррупция (включая взятки, дискриминацию и предоставление преференций отдельным участникам на заведомо неравных условиях) </td><td> nan </td>  <td> 32 </td><td> Коррупция (включая взятки, дискриминацию и предоставление преференций отдельным участникам на заведомо неравных условиях) </td>  <td> 1 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Сложность/затянутость процедуры получения лицензий </td><td> nan </td>  <td> 33 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Высокие налоги </td><td> Высокие налоги </td>  <td> 25 </td><td> nan </td>  <td> 8 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Необходимость установления партнерских отношений с органами власти </td><td> nan </td>  <td> 33 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Ограничение/сложность доступа к закупкам компаний с государственным участием и субъектов естественных монополий </td><td> nan </td>  <td> 33 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Ограничение/сложность доступа к поставкам товаров, оказанию услуг и выполнению работ в рамках государственных закупок </td><td> nan </td>  <td> 33 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Ограничение органами власти инициатив по организации совместной деятельности малых предприятий (например, в части создания совместных предприя ...

# %%
# Тепловая карта
cat = ["Ограничение органами власти инициатив по организации совместной деятельности малых предприятий (например, в части создания совместных предприятий, кооперативов и др.)",
       "Ограничение/сложность доступа к закупкам компаний с государственным участием и субъектов естественных монополий",
       "Нестабильность российского законодательства, регулирующего предпринимательскую деятельность",
       "Высокие налоги",
       "Ограничение/сложность доступа к поставкам товаров, оказанию услуг и выполнению работ в рамках государственных закупок",
       "Необходимость установления партнерских отношений с органами власти",
       "Иные действия/давление со стороны органов власти, препятствующие ведению бизнеса на рынке или входу на рынок новых участников",
       "Сложность получения доступа к земельным участкам",
       "Коррупция (включая взятки, дискриминацию и предоставление преференций отдельным участникам на заведомо неравных условиях)", np.nan]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %%
 #make_hist(kin_data.iloc[:, st:end])

# %%
# СТАЛКИВАЛИСЬ ЛИ ВЫ С ДИСКРИМИНАЦИЕЙ (НЕРАВНЫМ ДОСТУПОМ, УЩЕМЛЕНИЕМ ПРАВ) ВАШЕЙ ОРГАНИЗАЦИИ НА СТАДИИ ОТКРЫТИЯ БИЗНЕСА
"""
answer = dict(Counter(kin_data.iloc[:, 40]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 40]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %% [markdown]
# ### Как бы Вы охарактеризовали деятельность органов власти на основном для бизнеса

# %%
#  Как бы Вы охарактеризовали деятельность органов власти на основном для бизнеса

answer = dict(Counter(kin_data.iloc[:, 47]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Скорее удовлетворен': 23, 'Скорее не удовлетворен': 9, 'Удовлетворен': 1}
# {'Скорее удовлетворен': 69.7, 'Скорее не удовлетворен': 27.27, 'Удовлетворен': 3.03, 'Всего': 33}

# %% [markdown]
# ### По Вашей оценке, насколько преодолимы административные барьеры для ведения текущей деятельности?

# %%
# По Вашей оценке, насколько преодолимы административные барьеры для ведения текущей деятельности
answer = dict(Counter(kin_data.iloc[:, 48]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Административные барьеры есть, но они преодолимы без существенных затрат': 16, 'Есть барьеры, преодолимые при осуществлении значительных затрат': 12, 'Есть непреодолимые административные барьеры': 5}
# {'Административные барьеры есть, но они преодолимы без существенных затрат': 48.48, 'Есть барьеры, преодолимые при осуществлении значительных затрат': 36.36, 'Есть непреодолимые административные барьеры': 15.15, 'Всего': 33}

# %%
make_hist(kin_data.iloc[:, 48])

# %% [markdown]
# ### Как изменился уровень административных барьеров на рынке, основном для бизнеса

# %%
# По Вашей оценке, как изменился уровень административных барьеров на рынке, основном для бизнеса,
answer = dict(Counter(kin_data.iloc[:, 49]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Бизнесу стало сложнее преодолевать административные барьеры, чем раньше': 16, 'Ранее административные барьеры отсутствовали, однако сейчас появились': 15, 'Уровень и количество административных барьеров не изменились': 2}
# {'Бизнесу стало сложнее преодолевать административные барьеры, чем раньше': 48.48, 'Ранее административные барьеры отсутствовали, однако сейчас появились': 45.45, 'Уровень и количество административных барьеров не изменились': 6.06, 'Всего': 33}

# %%
#  КАК БЫ ВЫ ОХАРАКТЕРИЗОВАЛИ ДЕЯТЕЛЬНОСТЬ ОРГАНОВ ВЛАСТИ НА ОСНОВНОМ ДЛЯ БИЗНЕСА
"""
answer = dict(Counter(kin_data.iloc[:, 44]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 44]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 44])

# %% [markdown]
# ### Оцените СРОК ПОЛУЧЕНИЯ ДОСТУПА к услугам ЕСТЕСТВЕННЫХ МОНОПОЛИЙ

# %%
# Оцените характеристики услуг субъектов естественных монополий (срок получения доступа)
st = 50
end = 55

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение </td><td> 3. Скорее не удовлетворительно </td>  <td> 13 </td><td> 1. Удовлетворительно </td>  <td> 9 </td><td> 4. Не удовлетворительно </td>  <td> 6 </td><td> 2. Скорее удовлетворительно </td>  <td> 5 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка </td><td> 3. Скорее не удовлетворительно </td>  <td> 14 </td><td> 2. Скорее удовлетворительно </td>  <td> 8 </td><td> 4. Не удовлетворительно </td>  <td> 7 </td><td> 1. Удовлетворительно </td>  <td> 4 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение </td><td> 2. Скорее удовлетворительно </td>  <td> 15 </td><td> 3. Скорее не удовлетворительно </td>  <td> 8 </td><td> 1. Удовлетворительно </td>  <td> 7 </td><td> 4. Не удовлетворительно </td>  <td> 3 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Электроснабжение </td><td> 3. Скорее не удовлетворительно </td>  <td> 13 </td><td> 2. Скорее удовлетворительно </td>  <td> 10 </td><td> 1. Удовлетворительно </td>  <td> 5 </td><td> 4. Не удовлетворительно </td>  <td> 5 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Теплоснабжение </td><td> 3. Скорее не удовлетворительно </td>  <td> 11 </td><td> 4. Не удовлетворительно </td>  <td> 8 </td><td> 1. Удовлетворительно </td>  <td> 7 </td><td> 2. Скорее удовлетворительно </td>  <td> 7 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Телефонная связь </td><td> 3. Скорее не удовлетворительно </td>  <td> 10 </td><td> 1. Удовлетворительно </td>  <td> 9 </td><td> 2. Скорее удовлетворительно </td>  <td> 9 </td><td> 4. Не удовлетворительно </td>  <td> 5 </td></tr></table>

# %%
# Тепловая карта
cat = ["1. Удовлетворительно", "2. Скорее удовлетворительно", "3. Скорее не удовлетворительно", "4. Не удовлетворительно","5. Затрудняюсь ответить" ]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### СЛОЖНОСТЬ ДОСТУПА к услугам ЕСТЕСТВЕННЫХ МОНОПОЛИЙ

# %%
# Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения)
st = 56
end = 61

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение </td><td> 3. Скорее не удовлетворительно </td>  <td> 11 </td><td> 2. Скорее удовлетворительно </td>  <td> 10 </td><td> 4. Не удовлетворительно </td>  <td> 6 </td><td> 1. Удовлетворительно </td>  <td> 6 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка </td><td> 2. Скорее удовлетворительно </td>  <td> 17 </td><td> 3. Скорее не удовлетворительно </td>  <td> 9 </td><td> 4. Не удовлетворительно </td>  <td> 5 </td><td> 1. Удовлетворительно </td>  <td> 2 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение </td><td> 2. Скорее удовлетворительно </td>  <td> 13 </td><td> 3. Скорее не удовлетворительно </td>  <td> 12 </td><td> 1. Удовлетворительно </td>  <td> 5 </td><td> 4. Не удовлетворительно </td>  <td> 3 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Электроснабжение </td><td> 2. Скорее удовлетворительно </td>  <td> 11 </td><td> 3. Скорее не удовлетворительно </td>  <td> 11 </td><td> 1. Удовлетворительно </td>  <td> 7 </td><td> 4. Не удовлетворительно </td>  <td> 4 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Теплоснабжение </td><td> 3. Скорее не удовлетворительно </td>  <td> 12 </td><td> 2. Скорее удовлетворительно </td>  <td> 9 </td><td> 1. Удовлетворительно </td>  <td> 7 </td><td> 4. Не удовлетворительно </td>  <td> 5 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Телефонная связь </td><td> 3. Скорее не удовлетворительно </td>  <td> 12 </td><td> 2. Скорее удовлетворительно </td>  <td> 10 </td><td> 1. Удовлетворительно </td>  <td> 6 </td><td> 4. Не удовлетворительно </td>  <td> 5 </td></tr></table>

# %%
# Тепловая карта
cat = ["1. Удовлетворительно", "2. Скорее удовлетворительно", "3. Скорее не удовлетворительно", "4. Не удовлетворительно","5. Затрудняюсь ответить" ]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### СТОИМОСТЬ ПОДКЛЮЧЕНИЯ услуг естественных монополий

# %%
# Оцените характеристики услуг субъектов естественных монополий (стоимость подключения)
st = 62
end = 67

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение </td><td> 3. Скорее не удовлетворительно </td>  <td> 12 </td><td> 4. Не удовлетворительно </td>  <td> 10 </td><td> 2. Скорее удовлетворительно </td>  <td> 7 </td><td> 1. Удовлетворительно </td>  <td> 4 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка </td><td> 2. Скорее удовлетворительно </td>  <td> 11 </td><td> 4. Не удовлетворительно </td>  <td> 10 </td><td> 3. Скорее не удовлетворительно </td>  <td> 9 </td><td> 1. Удовлетворительно </td>  <td> 3 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение </td><td> 3. Скорее не удовлетворительно </td>  <td> 15 </td><td> 4. Не удовлетворительно </td>  <td> 8 </td><td> 2. Скорее удовлетворительно </td>  <td> 8 </td><td> 1. Удовлетворительно </td>  <td> 2 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Электроснабжение </td><td> 3. Скорее не удовлетворительно </td>  <td> 14 </td><td> 2. Скорее удовлетворительно </td>  <td> 7 </td><td> 4. Не удовлетворительно </td>  <td> 7 </td><td> 1. Удовлетворительно </td>  <td> 5 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Теплоснабжение </td><td> 2. Скорее удовлетворительно </td>  <td> 11 </td><td> 3. Скорее не удовлетворительно </td>  <td> 9 </td><td> 4. Не удовлетворительно </td>  <td> 7 </td><td> 1. Удовлетворительно </td>  <td> 6 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Телефонная связь </td><td> 3. Скорее не удовлетворительно </td>  <td> 12 </td><td> 2. Скорее удовлетворительно </td>  <td> 10 </td><td> 4. Не удовлетворительно </td>  <td> 6 </td><td> 1. Удовлетворительно </td>  <td> 4 </td><td> 5. Затрудняюсь ответить </td>  <td> 1 </td></tr></table>

# %%
# Тепловая карта
cat = ["1. Удовлетворительно", "2. Скорее удовлетворительно", "3. Скорее не удовлетворительно", "4. Не удовлетворительно","5. Затрудняюсь ответить" ]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, КОЛЛИЧЕСТВО ПРОЦЕДУР

# %%
# Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, КОЛЛИЧЕСТВО ПРОЦЕДУР
st = 68
end = 72

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к электросетям </td><td> 3-5 </td>  <td> 12 </td><td> 2 </td>  <td> 10 </td><td> 6-8 </td>  <td> 10 </td><td> 9 и более </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к сетям водоснабжения и водоотведения </td><td> 3-5 </td>  <td> 15 </td><td> 2 </td>  <td> 10 </td><td> 6-8 </td>  <td> 7 </td><td> nan </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к тепловым сетям </td><td> 3-5 </td>  <td> 16 </td><td> 6-8 </td>  <td> 11 </td><td> 2 </td>  <td> 4 </td><td> nan </td>  <td> 1 </td><td> 9 и более </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к телефонной сети </td><td> 3-5 </td>  <td> 15 </td><td> 2 </td>  <td> 9 </td><td> 6-8 </td>  <td> 8 </td><td> 9 и более </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Получение доступа к земельному участку </td><td> 6-8 </td>  <td> 14 </td><td> 3-5 </td>  <td> 9 </td><td> 2 </td>  <td> 8 </td><td> nan </td>  <td> 1 </td><td> 9 и более </td>  <td> 1 </td></tr></table>

# %%
# Тепловая карта
cat = ["1", "2", "3-5", "6-8","9 и более", np.nan]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур) (пожалуйста, укажите примерные значения или интервал значений) /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, СРОК ПОДКЛЮЧЕНИЯ

# %%
# Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, СРОК ПОДКЛЮЧЕНИЯ
st = 73
end = 77

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к электросетям </td><td> 51-90 дней </td>  <td> 16 </td><td> до 50 дней </td>  <td> 8 </td><td> 91-150 дней </td>  <td> 6 </td><td> 121-180 дней </td>  <td> 3 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к сетям водоснабжения и водоотведения </td><td> 51-90 дней </td>  <td> 11 </td><td> до 50 дней </td>  <td> 10 </td><td> 91-150 дней </td>  <td> 8 </td><td> 121-180 дней </td>  <td> 3 </td><td> nan </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к тепловым сетям </td><td> 51-90 дней </td>  <td> 15 </td><td> 91-150 дней </td>  <td> 10 </td><td> до 50 дней </td>  <td> 4 </td><td> 121-180 дней </td>  <td> 3 </td><td> nan </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к телефонной сети </td><td> 51-90 дней </td>  <td> 13 </td><td> до 50 дней </td>  <td> 10 </td><td> 91-150 дней </td>  <td> 8 </td><td> 121-180 дней </td>  <td> 2 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Получение доступа к земельному участку </td><td> 51-90 дней </td>  <td> 17 </td><td> 91-150 дней </td>  <td> 8 </td><td> до 50 дней </td>  <td> 7 </td><td> nan </td>  <td> 1 </td></tr></table>

# %%
# Тепловая карта
cat = ["до 50 дней", "51-90 дней", "91-150 дней", "121-180 дней", np.nan]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения (пожалуйста, укажите примерные значения или интервал значений)" /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %%
# ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ?
"""
st = 73
end = 82

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""

# %% [markdown]
# ### Как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий

# %%
# Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий
st = 78
end = 83

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение </td><td> Увеличилось </td>  <td> 19 </td><td> Не изменилось </td>  <td> 7 </td><td> Снизилось </td>  <td> 7 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка </td><td> Снизилось </td>  <td> 14 </td><td> Увеличилось </td>  <td> 12 </td><td> Не изменилось </td>  <td> 7 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение </td><td> Снизилось </td>  <td> 14 </td><td> Увеличилось </td>  <td> 13 </td><td> Не изменилось </td>  <td> 6 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Электроснабжение </td><td> Увеличилось </td>  <td> 19 </td><td> Снизилось </td>  <td> 8 </td><td> Не изменилось </td>  <td> 6 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Теплоснабжение </td><td> Увеличилось </td>  <td> 13 </td><td> Снизилось </td>  <td> 11 </td><td> Не изменилось </td>  <td> 9 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Телефонная связь </td><td> Увеличилось </td>  <td> 17 </td><td> Не изменилось </td>  <td> 8 </td><td> Снизилось </td>  <td> 8 </td></tr></table>

# %%
# Тепловая карта
cat = ["Снизилось", "Не изменилось", "Увеличилось"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Как изменилось КАЧЕСТВО УСЛУГ субъектов естественных монополий

# %%
#  Оцените, пожалуйста, как изменилось КАЧЕСТВО УСЛУГ субъектов естественных монополий, предоставляемых по месту
st = 84
end = 89

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение </td><td> Улучшилось </td>  <td> 15 </td><td> Не изменилось </td>  <td> 15 </td><td> Ухудшилось </td>  <td> 3 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка </td><td> Улучшилось </td>  <td> 18 </td><td> Не изменилось </td>  <td> 9 </td><td> Ухудшилось </td>  <td> 6 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение </td><td> Улучшилось </td>  <td> 18 </td><td> Не изменилось </td>  <td> 13 </td><td> Ухудшилось </td>  <td> 2 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Электроснабжение </td><td> Улучшилось </td>  <td> 18 </td><td> Не изменилось </td>  <td> 12 </td><td> Ухудшилось </td>  <td> 3 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Теплоснабжение </td><td> Улучшилось </td>  <td> 20 </td><td> Не изменилось </td>  <td> 10 </td><td> Ухудшилось </td>  <td> 3 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Телефонная связь </td><td> Улучшилось </td>  <td> 17 </td><td> Не изменилось </td>  <td> 12 </td><td> Ухудшилось </td>  <td> 4 </td></tr></table>

# %%
# Тепловая карта
cat = ["Улучшилось", "Не изменилось", "Ухудшилось"]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Как изменился УРОВЕНЬ ЦЕН на услуги субъектов естественных монополий

# %%
# Оцените, пожалуйста, как изменился УРОВЕНЬ ЦЕН на услуги субъектов естественных монополий
st = 90
end = 95

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение </td><td> Увеличился </td>  <td> 24 </td><td> Снизился </td>  <td> 6 </td><td> Не изменился </td>  <td> 3 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка </td><td> Увеличился </td>  <td> 17 </td><td> Не изменился </td>  <td> 8 </td><td> Снизился </td>  <td> 8 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение </td><td> Увеличился </td>  <td> 23 </td><td> Снизился </td>  <td> 5 </td><td> Не изменился </td>  <td> 5 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Электроснабжение </td><td> Увеличился </td>  <td> 18 </td><td> Не изменился </td>  <td> 8 </td><td> Снизился </td>  <td> 7 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Теплоснабжение </td><td> Увеличился </td>  <td> 22 </td><td> Не изменился </td>  <td> 7 </td><td> Снизился </td>  <td> 4 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Телефонная связь </td><td> Увеличился </td>  <td> 22 </td><td> Не изменился </td>  <td> 6 </td><td> Снизился </td>  <td> 5 </td></tr></table>

# %%
# Тепловая карта
cat = ["Увеличился", "Не изменился", "Снизился"]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий?

# %%
# С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий?
st = 96
end = 102

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
# Out:
# <table> <tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Взимание дополнительной платы </td><td> nan </td>  <td> 26 </td><td> Взимание дополнительной платы </td>  <td> 7 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Навязывание дополнительных услуг </td><td> nan </td>  <td> 31 </td><td> Навязывание дополнительных услуг </td>  <td> 2 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Отказ в установке приборов учета </td><td> nan </td>  <td> 33 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Проблемы с заменой приборов учета </td><td> nan </td>  <td> 29 </td><td> Проблемы с заменой приборов учета </td>  <td> 4 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Требование заказа необходимых работ у подконтрольных коммерческих структур </td><td> nan </td>  <td> 23 </td><td> Требование заказа необходимых работ у подконтрольных коммерческих структур </td>  <td> 10 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Не сталкивался с подобными проблемами </td><td> nan </td>  <td> 20 </td><td> Не сталкивался с подобными проблемами </td>  <td> 13 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Затрудняюсь ответить </td><td> nan </td>  <td> 32 </td><td> Затрудняюсь ответить </td>  <td> 1 </td></tr></table>

# %%
# Тепловая карта
cat = ["Взимание дополнительной платы", "Навязывание дополнительных услуг", "Отказ в установке приборов учета" , "Проблемы с заменой приборов учета",
       "Требование заказа необходимых работ у подконтрольных коммерческих структур", "Не сталкивался с подобными проблемами", "Затрудняюсь ответить", np.nan ]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Сталкивались ли Вы с дискриминационными  условиями доступа на товарный рынок

# %%
# Сталкивались ли Вы с дискриминационными  условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете
st = 103
end = 108

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
# Out:
# <table> <tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их </td><td> nan </td>  <td> 33 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Ценовая дискриминация </td><td> Ценовая дискриминация </td>  <td> 17 </td><td> nan </td>  <td> 16 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки </td><td> nan </td>  <td> 28 </td><td> Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки </td>  <td> 5 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности </td><td> nan </td>  <td> 32 </td><td> Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности </td>  <td> 1 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Не сталкивался </td><td> nan </td>  <td> 26 </td><td> Не сталкивался </td>  <td> 7 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Затрудняюсь ответить </td><td> nan </td>  <td> 29 </td><td> Затрудняюсь ответить </td>  <td> 4 </td></tr></table>

# %%
# Тепловая карта
cat = ["Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их",
       "Ценовая дискриминация",
       "Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки",
       "Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности",
       "Не сталкивался",
       "Затрудняюсь ответить",
       "Со всеми перечисленными дискриминационными условиями",
       np.nan]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %%
#kin_data.iloc[:, 109]

# %% [markdown]
# ### Неиспользуемы вопросы

# %%
# make_hist(kin_data.iloc[:, 102])

# %%
# Оцените КАЧЕСТВО УСЛУГ по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
"""
st = 103
end = 106

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""

# %%
# Оцените СТОИМОСТЬ УСЛУГ по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
"""
st = 107
end = 110

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""

# %%
# Оцените, пожалуйста, как изменилось качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном
"""
st = 111
end = 114

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""

# %%
# Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
"""
st = 115
end = 118

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""
