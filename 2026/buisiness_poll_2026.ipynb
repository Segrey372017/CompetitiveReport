# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Загрузка данных опроса

# %%
link = "https://github.com/Segrey372017/CompetitiveReport/raw/refs/heads/main/2026/buisiness_poll_2026.xlsx"

# %%
data = pd.read_excel(link)

# %%
data.head()
# Out:
#            ID       Время создания  \
# 0  2267323977  2026-01-14 08:36:31
# 1  2267370032  2026-01-14 09:32:46
# 2  2267374834  2026-01-14 09:38:04
# 3  2267378530  2026-01-14 09:42:10
# 4  2267381796  2026-01-14 09:45:50
#
#   В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?  \
# 0                    Кинешемский муниципальный район
# 1                             Городской округ Вичуга
# 2                             Городской округ Вичуга
# 3                             Городской округ Вичуга
# 4                             Городской округ Вичуга
#
#   Укажите, являетесь ли Вы юридическим лицом или имеете статус индивидуального предпринимателя  \
# 0                                   Юридическое лицо
# 1                                   Юридическое лицо
# 2                      Индивидуальный предпринматель
# 3                      Индивидуальный предпринматель
# ...

# %% [markdown]
# ### Список вопросов (колонок)

# %%
for i in range(len(data.columns)):
    print(i,'. ',data.columns[i])
# Out:
# 0 .  ID
# 1 .  Время создания
# 2 .  В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?
# 3 .  Укажите, являетесь ли Вы юридическим лицом или имеете статус индивидуального предпринимателя
# 4 .  В течение какого периода времени Ваш бизнес осуществляет свою деятельность? (пожалуйста, выберите один вариант ответа)
# 5 .  Какова численность сотрудников вашей организации в настоящее время? (пожалуйста, выберите один вариант ответа)
# 6 .  Какую должность Вы занимаете в организации, которую Вы представляете? (пожалуйста, выберите все подходящие варианты ответа)
# 7 .  Какова примерная величина годового оборота бизнеса, который Вы представляете? (пожалуйста, выберите один вариант ответа)
# 8 .  К какой сфере экономической деятельности относится Ваш бизнес, который Вы представляете? (пожалуйста, отметьте основной вид деятельности бизнеса, который Вы представляете)
# ...

# %%
def make_hist(d_info):
    "Выодит гистограму по полученным данным"
    plt.figure(figsize= (8,6))
    sns.histplot(d_info)
    plt.xticks(rotation = 90)
    plt.ylabel('Число опрошенных')
    plt.show()
    return

# %%
def calc_percent(cnt, r = 2):
    """ Считает процентное соотношение числа опрошенных,всего опрошенных 100%
        r - окгугление до r знаков после запятой
    """
    s = sum(cnt.values())
    p_cnt = dict()

    for key in cnt.keys():
        p_cnt[key] = round(cnt[key] / s * 100, r)

    p_cnt['Всего'] = s
    return p_cnt

# %%
from collections import Counter
cities = dict(Counter(data[data.columns[2]]).most_common())
print(cities)
print(calc_percent(cities))
# Out:
# {'Городской округ Иваново': 55, 'Городской округ Кинешма': 48, 'Приволжский муниципальный район': 35, 'Тейковский муниципальный район': 35, 'Ивановский муниципальный район': 35, 'Кинешемский муниципальный район': 33, 'Городской округ Шуя': 33, 'Юрьевецкий муниципальный район': 33, 'Родниковский муниципальный район': 33, 'Городской округ Вичуга': 32, 'Савинский муниципальный район': 32, 'Фурмановский муниципальный район': 32, 'Комсомольский муниципальный район': 31, 'Вичугский муниципальный район': 31, 'Верхнеландеховский муниципальный район': 31, 'Городской округ Кохма': 31, 'Городской округ Тейково': 31, 'Лежневский муниципальный район': 31, 'Лухский муниципальный район': 31, 'Пучежский муниципальный район': 31, 'Южский муниципальный район': 31, 'Гаврилово-Посадский муниципальный район': 31, 'Заволжский муниципальный район': 30, 'Палехский муниципальный район': 30, 'Пестяковский муниципальный район': 30, 'Шуйский муниципальный район': 30, 'Ильинский муниципальный район': 20}
# ...

# %%
data.iloc[:, 2].value_counts()
# Out:
# В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?
# Городской округ Иваново                    55
# Городской округ Кинешма                    48
# Тейковский муниципальный район             35
# Ивановский муниципальный район             35
# Приволжский муниципальный район            35
# Городской округ Шуя                        33
# Родниковский муниципальный район           33
# Юрьевецкий муниципальный район             33
# Кинешемский муниципальный район            33
# Савинский муниципальный район              32
# Городской округ Вичуга                     32
# Фурмановский муниципальный район           32
# Южский муниципальный район                 31
# Верхнеландеховский муниципальный район     31
# Вичугский муниципальный район              31
# Комсомольский муниципальный район          31
# Городской округ Кохма                      31
# Лухский муниципальный район                31
# ...

# %%
make_hist(data.iloc[:, 2])

# %% [markdown]
# # Выбор данных по Кинешме

# %%
kin_index = data.index[data[data.columns[2]].values=='Городской округ Кинешма']
kin_data = data.iloc[kin_index,:]
del data

# %%
kin_data.head()
# Out:
#              ID       Время создания  \
# 14   2267772298  2026-01-14 14:55:59
# 297  2273843035  2026-01-20 16:44:40
# 801  2292705842  2026-02-04 15:46:48
# 802  2292707295  2026-02-04 15:47:48
# 804  2292710196  2026-02-04 15:49:46
#
#     В каком муниципальном районе (городском округе) Ивановской  области вы ведете вашу предпринимательскую деятельность?  \
# 14                             Городской округ Кинешма
# 297                            Городской округ Кинешма
# 801                            Городской округ Кинешма
# 802                            Городской округ Кинешма
# 804                            Городской округ Кинешма
#
#     Укажите, являетесь ли Вы юридическим лицом или имеете статус индивидуального предпринимателя  \
# 14                       Индивидуальный предпринматель
# 297                      Индивидуальный предпринматель
# 801                      Индивидуальный предпринматель
# 802                      Индивидуальный предпринматель
# ...

# %% [markdown]
# ## Общие вопросы

# %%
# Форма осуществления деятельности
form = dict(Counter(kin_data.iloc[:, 3]).most_common())
print(form)
print(calc_percent(form))
del form
# Out:
# {'Индивидуальный предпринматель': 28, 'Юридическое лицо': 20}
# {'Индивидуальный предпринматель': 58.33, 'Юридическое лицо': 41.67, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 3])

# %%
#  В течении какого периода времени Ваш бизнес осуществляет свою деятельность?
b_age = dict(Counter(kin_data.iloc[:, 4]).most_common())
print(b_age)
print(calc_percent(b_age))
del b_age
# Out:
# {'От 1 года до 5 лет': 27, 'Более 5 лет': 21}
# {'От 1 года до 5 лет': 56.25, 'Более 5 лет': 43.75, 'Всего': 48}

# %%
# Какую должность Вы занимаете в организации, которую Вы представляете?
employee = dict(Counter(kin_data.iloc[:, 6]).most_common())
print(employee)
print(calc_percent(employee))
del employee
# Out:
# {'Собственник бизнеса (совладелец)': 39, 'Руководитель среднего звена (руководитель управления/подразделения/отдела)': 9}
# {'Собственник бизнеса (совладелец)': 81.25, 'Руководитель среднего звена (руководитель управления/подразделения/отдела)': 18.75, 'Всего': 48}

# %%
# Какова численность сотрудников Вашей организации в настоящее время?
employee = dict(Counter(kin_data.iloc[:, 5]).most_common())
print(employee)
print(calc_percent(employee))
del employee
# Out:
# {'До 15 человек': 40, 'От 16 до 100 человек': 8}
# {'До 15 человек': 83.33, 'От 16 до 100 человек': 16.67, 'Всего': 48}

# %%
# Какова примерная величина годового оборота бизнеса, который вы представляете?
turnover = dict(Counter(kin_data.iloc[:, 7]).most_common())
print(turnover)
print(calc_percent(turnover))
del turnover
# Out:
# {'До 120 млн. рублей': 48}
# {'До 120 млн. рублей': 100.0, 'Всего': 48}

# %%
# К какой социально-значимой сфере экономической деятельности относится деятельность бизнеса, которой вы представляете?
otrasl = dict(Counter(kin_data.iloc[:, 8]).most_common())
print(otrasl)
print(calc_percent(otrasl))
del otrasl
# Out:
# {'Рынок легкой промышленности': 18, 'Рынок услуг по ремонту автотранспортных средств': 14, 'Рынок строительства объектов капитального строительства, за исключением жилищного и дорожного строительства': 11, 'Сфера наружной рекламы': 4, 'Рынок социальных услуг': 1}
# {'Рынок легкой промышленности': 37.5, 'Рынок услуг по ремонту автотранспортных средств': 29.17, 'Рынок строительства объектов капитального строительства, за исключением жилищного и дорожного строительства': 22.92, 'Сфера наружной рекламы': 8.33, 'Рынок социальных услуг': 2.08, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 8])

# %%
# Основной продукцией (товаром, работой, услугой) бизнеса, который Вы представляете, является (пожалуйста, выберите один вариант ответа)
okved = dict(Counter(kin_data.iloc[:, 9]).most_common())
print(okved)
print(calc_percent(okved))
del okved
# Out:
# {'Услуги': 26, 'Компоненты для производства конечной продукции': 12, 'Конечная продукция': 5, 'Бизнес осуществляет торговлю или дистрибуцию товаров и услуг, произведенных другими компаниями': 5}
# {'Услуги': 54.17, 'Компоненты для производства конечной продукции': 25.0, 'Конечная продукция': 10.42, 'Бизнес осуществляет торговлю или дистрибуцию товаров и услуг, произведенных другими компаниями': 10.42, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 9])

# %%
# Какой географический рынок (рынки) является основным (рынок, на котором регулярно реализуется наибольшая доля продукции (товара, работы, услуги) для бизнеса, который Вы представляете?
product = dict(Counter(kin_data.iloc[:, 10]).most_common())
print(product)
print(calc_percent(product))
del product
# Out:
# {'Рынок нескольких субъектов Российской Федерации': 21, 'Региональный рынок': 20, 'Локальный рынок': 6, 'Рынок Российской Федерации': 1}
# {'Рынок нескольких субъектов Российской Федерации': 43.75, 'Региональный рынок': 41.67, 'Локальный рынок': 12.5, 'Рынок Российской Федерации': 2.08, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 10])

# %%
# Какую именно продукцию (товары, работы, услуги) реализует бизнес, который вы представляете?
"""
product = dict(Counter(kin_data.iloc[:, 10]).most_common())
print(product)
print(calc_percent(product))
del product
"""
# Out:
# '\nproduct = dict(Counter(kin_data.iloc[:, 10]).most_common())\nprint(product)\nprint(calc_percent(product))\ndel product\n'

# %%
#make_hist(kin_data.iloc[:, 10])

# %% [markdown]
# ## Конкурентоспособность бизнеса

# %% [markdown]
# ### Укажите, какие меры по повышению конкурентоспособности продукции, работ, услуг

# %%
# Укажите, какие меры по повышению конкурентоспособности продукции, работ, услуг, которые производит или предоставляет Ваш бизнес

mesures = dict(Counter(kin_data.iloc[:, 12]).most_common())
print(mesures)
print(calc_percent(mesures))
del mesures
# Out:
# {'Обучение и переподготовка персонала': 18, 'Новые способы продвижения продукции (маркетинговые стратегии)': 17, 'Приобретение технического оборудования': 7, 'Разработка новых модификаций и форм производимой продукции, расширение ассортимента': 6}
# {'Обучение и переподготовка персонала': 37.5, 'Новые способы продвижения продукции (маркетинговые стратегии)': 35.42, 'Приобретение технического оборудования': 14.58, 'Разработка новых модификаций и форм производимой продукции, расширение ассортимента': 12.5, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 12])

# %%
# Какой географический рынок (рынки) является основным* для бизнеса
"""
area = dict(Counter(kin_data.iloc[:, 12]).most_common())
print(area)
print(calc_percent(area))
del area
"""
# Out:
# '\narea = dict(Counter(kin_data.iloc[:, 12]).most_common())\nprint(area)\nprint(calc_percent(area))\ndel area\n'

# %% [markdown]
# ### Выберите утверждение, наиболее точно характеризующее условия ведения бизнеса

# %%
# Выберите утверждение, наиболее точно характеризующее условия ведения бизнеса, который Вы представляете (пожалуйста, укажите один наиболее подходящий вариант ответа):
answer = dict(Counter(kin_data.iloc[:, 11]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Для сохранения рыночной позиции нашего бизнеса необходимо регулярно (раз в год или чаще) предпринимать меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - умеренная конкуренция': 25, 'Для сохранения рыночной позиции нашего бизнеса время от времени (раз в 2 - 3 года) может потребоваться реализация мер по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - слабая конкуренция': 11, 'Для сохранения рыночной позиции нашего бизнеса нет необходимости реализовывать какие-либо меры по повышению конкурентоспособности нашей продукции/работ/услуг (снижение цен, повышение качества, развитие сопутствующих услуг, иное) - нет конкуренции': 10, 'Для сохранения рыночной позиции нашего бизнеса необходимо постоянно (раз в год и чаще) применять новые способы повышения конкурентоспособности нашей продукции/работ/услуг (снижение цен, пов
# ...

# %%
make_hist(kin_data.iloc[:, 11])

# %% [markdown]
# ### Оцените примерное количество конкурентов бизнеса

# %%
# Оцените примерное количество конкурентов бизнеса, который Вы представляете, предлагающих аналогичную продукцию (товар, работу, услугу) или ее заменители,
answer = dict(Counter(kin_data.iloc[:, 13]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Большое число конкурентов': 20, 'От 4 до 8 конкурентов': 18, 'От 1 до 3 конкурентов': 10}
# {'Большое число конкурентов': 41.67, 'От 4 до 8 конкурентов': 37.5, 'От 1 до 3 конкурентов': 20.83, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 13])

# %% [markdown]
# ### Как изменилось число конкурентов бизнеса

# %%
# Как изменилось число конкурентов бизнеса, который Вы представляете, на основном рынке товаров и услуг за последние 3 года?
answer = dict(Counter(kin_data.iloc[:, 14]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Увеличилось более чем на 4 конкурента': 34, 'Увеличилось на 1 - 3 конкурента': 8, 'Не изменилось': 6}
# {'Увеличилось более чем на 4 конкурента': 70.83, 'Увеличилось на 1 - 3 конкурента': 16.67, 'Не изменилось': 12.5, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 14])

# %% [markdown]
# ## Доступность информации

# %% [markdown]
# ### Оцените качество официальной информации о состоянии конкурентной среды

# %%
# Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг ивановской области
from IPython.display import HTML, display
st = 15
end = 17

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Уровень доступности </td><td> Скорее удовлетворительно </td>  <td> 23 </td><td> Удовлетворительно </td>  <td> 13 </td><td> Скорее неудовлетворительно </td>  <td> 11 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td></tr><tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: / Уровень понятности </td><td> Скорее удовлетворительно </td>  <td> 31 </td><td> Скорее неудовлетворительно </td>  <td> 10 </td><td> Удовлетворительно </td>  <td> 6 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td></tr><tr> <td> Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в откры
# ...

# %%
def fill_freq_mat(data, cats, columns):
    N = data.shape[0]
    M = data.shape[1]

    freq_mat = {}
    for col in cats:  # создаем матрицу для подсчета категорий
        freq_mat[col] = np.zeros(len(columns))

    for i in range(N):
        for j in range(M):
            freq_mat[data.iloc[i,j]][j] += 1

    return pd.DataFrame(data = freq_mat, index = columns)

# %%
# Тепловая карта
cat = ["Удовлетворительно", "Скорее удовлетворительно", "Скорее неудовлетворительно", "Затрудняюсь ответить/мне ничего не известно о такой информации"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените качество официальной информации о состоянии конкурентной среды на рынках товаров и услуг Ивановской области, размещаемой в открытом доступе: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Оцените полноту информации

# %%
# Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации
st = 18
end = 23

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: / Доступность информации о нормативной базе, связанной с внедрением Стандарта в регионе </td><td> Скорее неудовлетворительно </td>  <td> 27 </td><td> Скорее удовлетворительно </td>  <td> 14 </td><td> Неудовлетворительно </td>  <td> 6 </td><td> Затрудняюсь ответить/мне ничего не известно о такой информации </td>  <td> 1 </td></tr><tr> <td> Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии 
# ...

# %%
# Тепловая карта
cat = ["Удовлетворительно", "Скорее удовлетворительно", "Скорее неудовлетворительно", "Неудовлетворительно", "Затрудняюсь ответить/мне ничего не известно о такой информации"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, на Ваш взгляд, полноту размещенной органом исполнительной власти субъекта Российской Федерации, уполномоченным содействовать развитию конкуренции (далее - уполномоченный орган), и муниципальными образованиями информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Источники информации о конкурентной среде

# %%
#  Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации
st = 24
end = 32

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на сайте уполномоченного органа в информационно-телекоммуникационной сети "Интернет" </td><td> Предпочитаю пользоваться </td>  <td> 30 </td><td> Доверяю больше всего </td>  <td> 18 </td></tr><tr> <td> Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: / Официальная информация, размещенная на интернет-портале об инвестиционной деятельности в субъекте Российской Федерации </td><td> Предпочитаю пользоваться </td>  <td> 31 </td><td> Доверяю больше всего </td>  <td> 17 </td></tr><tr> <td> Укажите, какими источникам
# ...

# %%
# Тепловая карта
cat = ["Доверяю больше всего", "Предпочитаю пользоваться"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Укажите, какими источниками информации о состоянии конкурентной среды на рынках товаров, работ и услуг субъекта Российской Федерации и деятельности по содействию развитию конкуренции Вы предпочитаете пользоваться и доверяете больше всего: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Внешние условия конкуренции

# %% [markdown]
# ### Пожалуйста, оцените примерное число поставщиков основного закупаемого товара

# %%
# Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает
st = 33
end = 34

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает представляемый Вами бизнес для производства и реализации собственной продукции (если применимо), а также Вашу удовлетворенность состоянием конкуренции между поставщиками этого товара (работы, услуги) (пожалуйста, выберите один вариант ответа для каждой строки) / Число поставщиков основного закупаемого товара (работы, услуги) </td><td> 2 - 3 поставщика/скорее неудовлетворительно </td>  <td> 19 </td><td> Единственный поставщик/неудовлетворительно </td>  <td> 12 </td><td> 4 и более поставщика/скорее удовлетворительно </td>  <td> 10 </td><td> Большое число поставщиков/удовлетворительно </td>  <td> 7 </td></tr><tr> <td> Пожалуйста, оцените примерное число поставщиков основного закупаемого товара (работы, услуги), который приобретает представляемый Вами бизнес для производства и реализации собственной продукции (если применимо), а также Вашу удовлетворенность
# ...

# %%
# ПОЖАЛУЙСТА, УКАЖИТЕ НАИМЕНОВАНИЕ ОСНОВНОГО ЗАКУПАЕМОГО ТОВАРА (РАБОТЫ, УСЛУГИ)
"""
answer = dict(Counter(kin_data.iloc[:, 35]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 35]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 35])

# %%
# Пожалуйста, укажите наименование товаров, работ, услуг, закупаемых представляемым вами бизнесом для производства
"""
answer = dict(Counter(kin_data.iloc[:, 36]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 36]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 36])

# %%
# КАКОЙ ОТРАСЛЕВОЙ РЫНОК В ВАШЕМ РАЙОНЕ/ГОРОДСКОМ ОКРУГЕ ВЫ СЧИТАЕТЕ ПРИОРИТЕТНЫМИ И СОЦИАЛЬНО-ЗНАЧИМЫМИ
"""
answer = dict(Counter(kin_data.iloc[:, 37]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 37]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 37])

# %%
# СЧИТАЕТЕ ЛИ ВЫ, ЧТО КОНКУРЕНЦИЯ НА ВАШЕМ ОТРАСЛЕВОМ РЫНКЕ В ВАШЕМ РАЙОНЕ/ГОРОДСКОМ ОКРУГЕ ИМЕЕТ ВЫСОКИЙ УРОВЕНЬ РАЗВИТИЯ
"""
answer = dict(Counter(kin_data.iloc[:, 38]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 38]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 38])

# %% [markdown]
# ## Административные барьеры, естественные монополии

# %% [markdown]
# ### Какие из перечисленных административных барьеров являются наиболее существенными

# %%
# По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности
st = 35
end = 46

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Сложность получения доступа к земельным участкам </td><td> nan </td>  <td> 46 </td><td> Сложность получения доступа к земельным участкам </td>  <td> 2 </td></tr><tr> <td> По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): / Нестабильность российского законодательства, регулирующего предпринимательскую деятельность </td><td> nan </td>  <td> 38 </td><td> Нестабильность российского законодательства, регулирующего предпринимательскую деятельность </td>  <td> 10 </td></tr><tr> <td> По Ваше
# ...

# %%
# Тепловая карта
cat = ["Ограничение органами власти инициатив по организации совместной деятельности малых предприятий (например, в части создания совместных предприятий, кооперативов и др.)",
       "Ограничение/сложность доступа к закупкам компаний с государственным участием и субъектов естественных монополий",
       "Нестабильность российского законодательства, регулирующего предпринимательскую деятельность",
       "Высокие налоги",
       "Ограничение/сложность доступа к поставкам товаров, оказанию услуг и выполнению работ в рамках государственных закупок",
       "Необходимость установления партнерских отношений с органами власти",
       "Иные действия/давление со стороны органов власти, препятствующие ведению бизнеса на рынке или входу на рынок новых участников",
       "Сложность получения доступа к земельным участкам",
       "Коррупция (включая взятки, дискриминацию и предоставление преференций отдельным участникам на заведомо неравных условиях)",
       "Сложность/затянутость процедуры получения лицензий",
       "Силовое давление со стороны правоохранительных органов (угрозы, вымогательства и т.д.)",
       np.nan]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'По Вашему мнению, какие из перечисленных административных барьеров являются наиболее существенными для ведения текущей деятельности или открытия нового бизнеса на рынке, основном для бизнеса, который Вы представляете? (пожалуйста, выберите не более 3 вариантов ответа): /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %%
 #make_hist(kin_data.iloc[:, st:end])

# %%
# СТАЛКИВАЛИСЬ ЛИ ВЫ С ДИСКРИМИНАЦИЕЙ (НЕРАВНЫМ ДОСТУПОМ, УЩЕМЛЕНИЕМ ПРАВ) ВАШЕЙ ОРГАНИЗАЦИИ НА СТАДИИ ОТКРЫТИЯ БИЗНЕСА
"""
answer = dict(Counter(kin_data.iloc[:, 40]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 40]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %% [markdown]
# ### Как бы Вы охарактеризовали деятельность органов власти на основном для бизнеса

# %%
#  Как бы Вы охарактеризовали деятельность органов власти на основном для бизнеса

answer = dict(Counter(kin_data.iloc[:, 47]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Скорее удовлетворен': 27, 'Скорее не удовлетворен': 20, 'Не удовлетворен': 1}
# {'Скорее удовлетворен': 56.25, 'Скорее не удовлетворен': 41.67, 'Не удовлетворен': 2.08, 'Всего': 48}

# %% [markdown]
# ### По Вашей оценке, насколько преодолимы административные барьеры для ведения текущей деятельности?

# %%
# По Вашей оценке, насколько преодолимы административные барьеры для ведения текущей деятельности
answer = dict(Counter(kin_data.iloc[:, 48]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Есть барьеры, преодолимые при осуществлении значительных затрат': 27, 'Есть непреодолимые административные барьеры': 16, 'Административные барьеры есть, но они преодолимы без существенных затрат': 5}
# {'Есть барьеры, преодолимые при осуществлении значительных затрат': 56.25, 'Есть непреодолимые административные барьеры': 33.33, 'Административные барьеры есть, но они преодолимы без существенных затрат': 10.42, 'Всего': 48}

# %%
make_hist(kin_data.iloc[:, 48])

# %% [markdown]
# ### Как изменился уровень административных барьеров на рынке, основном для бизнеса

# %%
# По Вашей оценке, как изменился уровень административных барьеров на рынке, основном для бизнеса,
answer = dict(Counter(kin_data.iloc[:, 49]).most_common())
print(answer)
print(calc_percent(answer))
del answer
# Out:
# {'Уровень и количество административных барьеров не изменились': 26, 'Бизнесу стало сложнее преодолевать административные барьеры, чем раньше': 21, 'Ранее административные барьеры отсутствовали, однако сейчас появились': 1}
# {'Уровень и количество административных барьеров не изменились': 54.17, 'Бизнесу стало сложнее преодолевать административные барьеры, чем раньше': 43.75, 'Ранее административные барьеры отсутствовали, однако сейчас появились': 2.08, 'Всего': 48}

# %%
#  КАК БЫ ВЫ ОХАРАКТЕРИЗОВАЛИ ДЕЯТЕЛЬНОСТЬ ОРГАНОВ ВЛАСТИ НА ОСНОВНОМ ДЛЯ БИЗНЕСА
"""
answer = dict(Counter(kin_data.iloc[:, 44]).most_common())
print(answer)
print(calc_percent(answer))
del answer
"""
# Out:
# '\nanswer = dict(Counter(kin_data.iloc[:, 44]).most_common())\nprint(answer)\nprint(calc_percent(answer))\ndel answer\n'

# %%
#make_hist(kin_data.iloc[:, 44])

# %% [markdown]
# ### Оцените СРОК ПОЛУЧЕНИЯ ДОСТУПА к услугам ЕСТЕСТВЕННЫХ МОНОПОЛИЙ

# %%
# Оцените характеристики услуг субъектов естественных монополий (срок получения доступа)
st = 50
end = 55

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение </td><td> 2. Скорее удовлетворительно </td>  <td> 21 </td><td> 3. Скорее не удовлетворительно </td>  <td> 15 </td><td> 4. Не удовлетворительно </td>  <td> 6 </td><td> 1. Удовлетворительно </td>  <td> 6 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка </td><td> 2. Скорее удовлетворительно </td>  <td> 19 </td><td> 3. Скорее не удовлетворительно </td>  <td> 16 </td><td> 4. Не удовлетворительно </td>  <td> 7 </td><td> 1. Удовлетворительно </td>  <td> 6 </td></tr><tr> <td> Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение </td><td> 2. Скорее удовлетворительно </td>  <td> 16 </td><td> 3. Скорее не 
# ...

# %%
# Тепловая карта
cat = ["1. Удовлетворительно", "2. Скорее удовлетворительно", "3. Скорее не удовлетворительно", "4. Не удовлетворительно","5. Затрудняюсь ответить" ]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените характеристики (сроки получения доступа) услуг субъектов естественных монополий в Ивановской области по следующим критериям: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### СЛОЖНОСТЬ ДОСТУПА к услугам ЕСТЕСТВЕННЫХ МОНОПОЛИЙ

# %%
# Оцените характеристики услуг субъектов естественных монополий (сложность процедуры подключения)
st = 56
end = 61

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение </td><td> 2. Скорее удовлетворительно </td>  <td> 23 </td><td> 3. Скорее не удовлетворительно </td>  <td> 17 </td><td> 4. Не удовлетворительно </td>  <td> 4 </td><td> 1. Удовлетворительно </td>  <td> 4 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка </td><td> 2. Скорее удовлетворительно </td>  <td> 23 </td><td> 3. Скорее не удовлетворительно </td>  <td> 16 </td><td> 1. Удовлетворительно </td>  <td> 5 </td><td> 4. Не удовлетворительно </td>  <td> 4 </td></tr><tr> <td> Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газ
# ...

# %%
# Тепловая карта
cat = ["1. Удовлетворительно", "2. Скорее удовлетворительно", "3. Скорее не удовлетворительно", "4. Не удовлетворительно","5. Затрудняюсь ответить" ]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените характеристики (количество процедур подключения, сложность получения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### СТОИМОСТЬ ПОДКЛЮЧЕНИЯ услуг естественных монополий

# %%
# Оцените характеристики услуг субъектов естественных монополий (стоимость подключения)
st = 62
end = 67

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоснабжение, водоотведение </td><td> 3. Скорее не удовлетворительно </td>  <td> 17 </td><td> 2. Скорее удовлетворительно </td>  <td> 16 </td><td> 4. Не удовлетворительно </td>  <td> 9 </td><td> 1. Удовлетворительно </td>  <td> 6 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Водоочистка </td><td> 3. Скорее не удовлетворительно </td>  <td> 16 </td><td> 2. Скорее удовлетворительно </td>  <td> 14 </td><td> 4. Не удовлетворительно </td>  <td> 10 </td><td> 1. Удовлетворительно </td>  <td> 8 </td></tr><tr> <td> Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: / Газоснабжение </td><td> 3. Скорее не удовлетворительно </td>  <td> 18 </td><td> 2. Скорее удовл
# ...

# %%
# Тепловая карта
cat = ["1. Удовлетворительно", "2. Скорее удовлетворительно", "3. Скорее не удовлетворительно", "4. Не удовлетворительно","5. Затрудняюсь ответить" ]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените характеристики (стоимость подключения) услуг субъектов естественных монополий в Ивановской области по следующим критериям: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, КОЛЛИЧЕСТВО ПРОЦЕДУР

# %%
# Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, КОЛЛИЧЕСТВО ПРОЦЕДУР
st = 68
end = 72

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к электросетям </td><td> 3-5 </td>  <td> 25 </td><td> 6-8 </td>  <td> 14 </td><td> 2 </td>  <td> 9 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений) / Подключение к сетям водоснабжения и водоотведения </td><td> 3-5 </td>  <td> 20 </td><td> 6-8 </td>  <td> 14 </td><td> 2 </td>  <td> 11 </td><td> 9 и более </td>  <td> 3 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур)  (пожалуйста, укажите примерные значения или интервал значений)
# ...

# %%
# Тепловая карта
cat = ["1", "2", "3-5", "6-8","9 и более", np.nan]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста, сложность (количество процедур) (пожалуйста, укажите примерные значения или интервал значений) /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, СРОК ПОДКЛЮЧЕНИЯ

# %%
# Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, СРОК ПОДКЛЮЧЕНИЯ
st = 73
end = 77

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к электросетям </td><td> 51-90 дней </td>  <td> 22 </td><td> 91-150 дней </td>  <td> 14 </td><td> до 50 дней </td>  <td> 11 </td><td> 121-180 дней </td>  <td> 1 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите примерные значения или интервал значений)" / Подключение к сетям водоснабжения и водоотведения </td><td> 91-150 дней </td>  <td> 17 </td><td> 51-90 дней </td>  <td> 16 </td><td> до 50 дней </td>  <td> 11 </td><td> 121-180 дней </td>  <td> 4 </td></tr><tr> <td> Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения  (пожалуйста, укажите п
# ...

# %%
# Тепловая карта
cat = ["до 50 дней", "51-90 дней", "91-150 дней", "121-180 дней", np.nan]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Если бизнес, который Вы представляете, сталкивался с процессом получения доступа к следующим услугам, оцените, пожалуйста сроки получения (пожалуйста, укажите примерные значения или интервал значений)" /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %%
# ОБРАЩАЛИСЬ ЛИ ВЫ В ТЕЧЕНИЕ ПОСЛЕДНИХ ТРЕХ ЛЕТ ЗА ЗАЩИТОЙ СВОИХ ПРАВ КАК ПРЕДПРИНИМАТЕЛЬ?
"""
st = 73
end = 82

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""
# Out:
# '\nst = 73\nend = 82\n\nhtml_str = "<table> "\nfor i in range(st, end+1):\n    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"\n    ans = dict(Counter(kin_data.iloc[:, i]).most_common())\n    for key in ans.keys():\n        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"\n    html_str += f"</tr>"\n\nhtml_str +=\'</table>\'\ndisplay(HTML(html_str))\n#print(html_str)\n'

# %% [markdown]
# ### Как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий

# %%
# Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий
st = 78
end = 83

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение </td><td> Увеличилось </td>  <td> 21 </td><td> Не изменилось </td>  <td> 16 </td><td> Снизилось </td>  <td> 11 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка </td><td> Увеличилось </td>  <td> 24 </td><td> Не изменилось </td>  <td> 14 </td><td> Снизилось </td>  <td> 10 </td></tr><tr> <td> Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение </td><td> Увеличилось </td>  <td> 23 </td><td> Не изменилось </td>  <td> 15 </td><td> Сниз
# ...

# %%
# Тепловая карта
cat = ["Снизилось", "Не изменилось", "Увеличилось"]

frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, как изменилась сложность (количество) процедур подключения услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Как изменилось КАЧЕСТВО УСЛУГ субъектов естественных монополий

# %%
#  Оцените, пожалуйста, как изменилось КАЧЕСТВО УСЛУГ субъектов естественных монополий, предоставляемых по месту
st = 84
end = 89

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение </td><td> Улучшилось </td>  <td> 25 </td><td> Не изменилось </td>  <td> 19 </td><td> Ухудшилось </td>  <td> 4 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка </td><td> Улучшилось </td>  <td> 26 </td><td> Не изменилось </td>  <td> 16 </td><td> Ухудшилось </td>  <td> 6 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение </td><td> Улучшилось </td>  <td> 22 </td><td> Не изменилось </td>  <td> 19 </td><td> Ухудшилось </td>  <td> 7 </td></tr><tr> <td> Оцените, пожалуйста, как изменилось качество услуг субъектов естест
# ...

# %%
# Тепловая карта
cat = ["Улучшилось", "Не изменилось", "Ухудшилось"]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, как изменилось качество услуг субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Как изменился УРОВЕНЬ ЦЕН на услуги субъектов естественных монополий

# %%
# Оцените, пожалуйста, как изменился УРОВЕНЬ ЦЕН на услуги субъектов естественных монополий
st = 90
end = 95

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
# Out:
# <table> <tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоснабжение, водоотведение </td><td> Увеличился </td>  <td> 35 </td><td> Снизился </td>  <td> 8 </td><td> Не изменился </td>  <td> 5 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Водоочистка </td><td> Увеличился </td>  <td> 35 </td><td> Не изменился </td>  <td> 8 </td><td> Снизился </td>  <td> 5 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: / Газоснабжение </td><td> Увеличился </td>  <td> 30 </td><td> Не изменился </td>  <td> 10 </td><td> Снизился </td>  <td> 8 </td></tr><tr> <td> Оцените, пожалуйста, как изменился уровень цен на услуги суб
# ...

# %%
# Тепловая карта
cat = ["Увеличился", "Не изменился", "Снизился"]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Оцените, пожалуйста, как изменился уровень цен на услуги субъектов естественных монополий, предоставляемых по месту ведения Вашего бизнеса, за последние 5 лет: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий?

# %%
# С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий?
st = 96
end = 102

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
# Out:
# <table> <tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Взимание дополнительной платы </td><td> nan </td>  <td> 35 </td><td> Взимание дополнительной платы </td>  <td> 13 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Навязывание дополнительных услуг </td><td> nan </td>  <td> 46 </td><td> Навязывание дополнительных услуг </td>  <td> 2 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Отказ в установке приборов учета </td><td> nan </td>  <td> 47 </td><td> Отказ в установке приборов учета </td>  <td> 1 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: / Проблемы с заменой приборов учета </td><td> nan </td>  <td> 46 </td><td> Проблемы с заменой приборов учета </td>  <td> 2 </td></tr><tr> <td> С какими проблемами Вы столкнулись при взаимодействии с
# ...

# %%
# Тепловая карта
cat = ["Взимание дополнительной платы", "Навязывание дополнительных услуг", "Отказ в установке приборов учета" , "Проблемы с заменой приборов учета",
       "Требование заказа необходимых работ у подконтрольных коммерческих структур", "Не сталкивался с подобными проблемами", "Затрудняюсь ответить", np.nan ]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'С какими проблемами Вы столкнулись при взаимодействии с субъектами естественных монополий: /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Сталкивались ли Вы с дискриминационными  условиями доступа на товарный рынок

# %%
# Сталкивались ли Вы с дискриминационными  условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете
st = 103
end = 108

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
# Out:
# <table> <tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их </td><td> nan </td>  <td> 48 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Ценовая дискриминация </td><td> nan </td>  <td> 32 </td><td> Ценовая дискриминация </td>  <td> 16 </td></tr><tr> <td> Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? / Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки </td><td> nan </td>  <td> 43 </td><td> Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки </td
# ...

# %%
# Тепловая карта
cat = ["Отсутствие организации и проведения торгов на право заключения договоров в случаях, когда законодательство требует их",
       "Ценовая дискриминация",
       "Продажа товара только в определенном ассортименте, продаже в нагрузку, разные условия поставки",
       "Акты органов государственной власти субъектов Российской Федерации, которые вводят ограничения в отношении создания хозяйствующих субъектов, осуществления ими отдельных видов деятельности",
       "Не сталкивался",
       "Затрудняюсь ответить",
       "Со всеми перечисленными дискриминационными условиями",
       np.nan]
frame = kin_data.iloc[:, st:end+1]
frame.shape

# сокращенные названия строк вопроса анкеты
tr = r'Сталкивались ли Вы с дискриминационными условиями доступа на товарный рынок, основной для бизнеса, который Вы представляете (укажите, с какими именно)? /'
columns = []
for col in frame.columns:
    columns.append(col[len(tr)+1:])

freq = fill_freq_mat(frame, cat, columns)


plt.figure(figsize = (18,9))
sns.heatmap(freq, vmin = 0, cmap ='viridis', linewidths= 1, annot = True, fmt ='0.1f')
# Out:
# <Axes: >

# %%
#kin_data.iloc[:, 109]

# %% [markdown]
# ### Неиспользуемы вопросы

# %%
# make_hist(kin_data.iloc[:, 102])

# %%
# Оцените КАЧЕСТВО УСЛУГ по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
"""
st = 103
end = 106

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""
# Out:
# '\nst = 103\nend = 106\n\nhtml_str = "<table> "\nfor i in range(st, end+1):\n    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"\n    ans = dict(Counter(kin_data.iloc[:, i]).most_common())\n    for key in ans.keys():\n        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"\n    html_str += f"</tr>"\n\nhtml_str +=\'</table>\'\ndisplay(HTML(html_str))\n#print(html_str)\n'

# %%
# Оцените СТОИМОСТЬ УСЛУГ по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
"""
st = 107
end = 110

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""
# Out:
# '\nst = 107\nend = 110\n\nhtml_str = "<table> "\nfor i in range(st, end+1):\n    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"\n    ans = dict(Counter(kin_data.iloc[:, i]).most_common())\n    for key in ans.keys():\n        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"\n    html_str += f"</tr>"\n\nhtml_str +=\'</table>\'\ndisplay(HTML(html_str))\n#print(html_str)\n'

# %%
# Оцените, пожалуйста, как изменилось качество услуг по техническому присоединению к сетям инженерно-технического обеспечения в электронном
"""
st = 111
end = 114

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""
# Out:
# '\nst = 111\nend = 114\n\nhtml_str = "<table> "\nfor i in range(st, end+1):\n    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"\n    ans = dict(Counter(kin_data.iloc[:, i]).most_common())\n    for key in ans.keys():\n        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"\n    html_str += f"</tr>"\n\nhtml_str +=\'</table>\'\ndisplay(HTML(html_str))\n#print(html_str)\n'

# %%
# Оцените, пожалуйста, как изменился уровень цен на услуги по техническому присоединению к сетям инженерно-технического обеспечения в электронном виде
"""
st = 115
end = 118

html_str = "<table> "
for i in range(st, end+1):
    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"
    ans = dict(Counter(kin_data.iloc[:, i]).most_common())
    for key in ans.keys():
        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"
    html_str += f"</tr>"

html_str +='</table>'
display(HTML(html_str))
#print(html_str)
"""
# Out:
# '\nst = 115\nend = 118\n\nhtml_str = "<table> "\nfor i in range(st, end+1):\n    html_str += f"<tr> <td> {kin_data.columns[i]} </td>"\n    ans = dict(Counter(kin_data.iloc[:, i]).most_common())\n    for key in ans.keys():\n        html_str += f"<td> {key} </td>  <td> {ans[key]} </td>"\n    html_str += f"</tr>"\n\nhtml_str +=\'</table>\'\ndisplay(HTML(html_str))\n#print(html_str)\n'
